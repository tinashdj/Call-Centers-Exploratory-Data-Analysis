# %% [markdown]
# ## Call Centers

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this project i use dataset from [data.world](https://data.world/markbradbourne/rwfd-real-world-fake-data/workspace/file?filename=Call+Center.csv) website. The dataset i'm going to use is from 'RWFD Real World Fake Data' by Mark Bradbourne, he have some datasets that we can use for free, and i picked one the call-center dataset.
#
# The call-center dataset that i'm going to use has 32,941 records of data that provide information about calls made to various call centers in North America. It includes the ID of the call , the customer name who called and also their reason, how long did the calls last in duration minutes, etc, that i'll use to explore the data.

# %% [markdown]
# ### Importing data

# %% [markdown]
# After downloading the call center data, we need to import it to our relational database system, in this case i will use postgresql.
#
# First we need to create a database inside the postgresql, i created mine as a project1, and in this database we are going to import our dataset. To import our dataset, we ned to create a table using a 'CREATE TABLE' syntax and next you write the table name 'calls', and then write the columns name with the data types and the size of the variable that will be in our 'calls' table. In the existing call center dataset we have 12 columns that include, the id, customer name, sentiment, city, reason, etc. So we are going to write the 12 columns in our database so it will be match with the existing call center dataset. Make sure to write the columns sequentially according to the call center datasets as the existing data.
#
# You can see or follow along the steps [here](https://github.com/tinashdj/Call-Center-Exploratory-Data-Analysis/blob/main/datasets/createdbs.sql).

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Exploratory Data Analysis (EDA) is the process of visualizing and analyzing data to extract insights from it. In other words, EDA is the process of summarizing important characteristics of data in order to gain better understanding of the dataset.
# [Source](https://medium.com/code-heroku/introduction-to-exploratory-data-analysis-eda-c0257f888676)

# %% [markdown]
# ### 1. How many call centers?

# %% [markdown]
# Lets see how many call centers do we have in the call center dataset

# %%
# %%sql
#
# SELECT DISTINCT call_center FROM calls
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 4 rows affected.
# [('Los Angeles/CA      ',),
#  ('Chicago/IL          ',),
#  ('Denver/CO           ',),
#  ('Baltimore/MD        ',)]

# %% [markdown]
# The results we have only 4 call centers which is in Los Angeles/CA, Chicago/IL, Denver/CO and Baltimore/MD.

# %% [markdown]
# ### 2. What is the most reason of the calls?

# %% [markdown]
# From the over 32.900 calls data, we want to know what is the reason of the calls and which one is be the most reason.

# %%
# %%sql
#
# SELECT reason, COUNT(*),
# ROUND(COUNT(*) * 100.0/ (SELECT COUNT(*) FROM calls) ,2) AS percentage
# FROM calls GROUP BY reason ORDER BY reason ASC;
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 3 rows affected.
# [('Billing Question    ', 23462, Decimal('71.22')),
#  ('Payments            ', 4749, Decimal('14.42')),
#  ('Service Outage      ', 4730, Decimal('14.36'))]

# %% [markdown]
# We get 3 reasons over the calls, and the most reason of the calls is about Billing Question with 71.22% and 23.462 total calls.
# Then we have still 2 reasons, Payments and Service Outage that really have a huge different total from the first one. Payments reason have 14.42% with 4.749 total of calls and it's almost have the same total with Service outage reason which have 14.36% with 4.730 total calls.

# %% [markdown]
# ### 3. Where is the city has the most calls and what is the reason?

# %% [markdown]
# Let's see what city has the most calls and also the reason.

# %%
# %%sql
#
# SELECT city, reason, COUNT(*) as total_calls
# FROM calls
# GROUP BY city,reason ORDER BY total_calls DESC;
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 1348 rows affected.
# [('Washington                                        ', 'Billing Question    ', 806),
#  ('Houston                                           ', 'Billing Question    ', 494),
#  ('New York City                                     ', 'Billing Question    ', 407),
#  ('El Paso                                           ', 'Billing Question    ', 374),
#  ('Dallas                                            ', 'Billing Question    ', 312),
#  ('Atlanta                                           ', 'Billing Question    ', 295),
#  ('Miami                                             ', 'Billing Question    ', 259),
#  ('Los Angeles                                       ', 'Billing Question    ', 243),
#  ('Kansas City                                       ', 'Billing Question    ', 231),
#  ('Sacramento                                        ', 'Billing Question    ', 226),
#  ('Chicago                                           ', 'Billing Question    ', 224),
#  ('Springfield                                       ', 'Billing Question    ', 219),
#  ('San Antonio                                       ', 'Billing Question    ', 217),
#  ('Oklahoma City                                     ', 'Billing Question    ', 205),
#  ('Austin                                            ', 'Billing Question    ', 203),
#  ('Phoenix                                           ', 'Billing Question    ', 201),
#  ('Richmond                                          ', 'Billing Question    ', 197),
#  ('Birmingham                                        ', 'Billing Question    ', 196),
#  ('Minneapolis                                       ', 'Billing Question    ', 191),
#  ('Cincinnati                                        ', 'Billing Question    ', 190),
#  ('Las Vegas                                         ', 'Billing Question    ', 190),
#  ('San Francisco                                     ', 'Billing Question    ', 188),
#  ('Seattle                                           ', 'Billing Question    ', 186),
#  ('Denver                                            ', 'Billing Question    ', 186),
#  ('Pittsburgh                                        ', 'Billing Question    ', 184),
#  ('Charlotte                                         ', 'Billing Question    ', 184),
#  ('New Orleans                                       ', 'Billing Question    ', 183),
#  ('Philadelphia                                      ', 'Billing Question    ', 182),
#  ('San Diego                                         ', 'Billing Question    ', 180),
#  ('Memphis                                           ', 'Billing Question    ', 178),
#  ('Saint Louis                                       ', 'Billing Question    ', 166),
#  ('Washington                                        ', 'Payments            ', 164),
#  ('Tampa                                             ', 'Billing Question    ', 162),
#  ('Tulsa                                             ', 'Billing Question    ', 160),
#  ('Orlando                                           ', 'Billing Question    ', 159),
#  ('Salt Lake City                                    ', 'Billing Question    ', 157),
#  ('Portland                                          ', 'Billing Question    ', 156),
#  ('Louisville                                        ', 'Billing Question    ', 155),
#  ('Indianapolis                                      ', 'Billing Question    ', 155),
#  ('Des Moines                                        ', 'Billing Question    ', 155),
#  ('Columbus                                          ', 'Billing Question    ', 154),
#  ('Charleston                                        ', 'Billing Question    ', 152),
#  ('Boston                                            ', 'Billing Question    ', 144),
#  ('Detroit                                           ', 'Billing Question    ', 143),
#  ('Rochester                                         ', 'Billing Question    ', 140),
#  ('Fresno                                            ', 'Billing Question    ', 140),
#  ('Washington                                        ', 'Service Outage      ', 140),
#  ('Arlington                                         ', 'Billing Question    ', 139),
#  ('Jacksonville                                      ', 'Billing Question    ', 138),
#  ('Baltimore                                         ', 'Billing Question    ', 133),
#  ('Fort Worth                                        ', 'Billing Question    ', 132),
#  ('San Jose                                          ', 'Billing Question    ', 131),
#  ('Colorado Springs                                  ', 'Billing Question    ', 129),
#  ('Albany                                            ', 'Billing Question    ', 128),
#  ('Saint Paul                                        ', 'Billing Question    ', 127),
#  ('Mobile                                            ', 'Billing Question    ', 125),
#  ('Roanoke                                           ', 'Billing Question    ', 125),
#  ('Nashville                                         ', 'Billing Question    ', 119),
#  ('Topeka                                            ', 'Billing Question    ', 119),
#  ('Dayton                                            ', 'Billing Question    ', 117),
#  ('Albuquerque                                       ', 'Billing Question    ', 117),
#  ('Tucson                                            ', 'Billing Question    ', 114),
#  ('Montgomery                                        ', 'Billing Question    ', 112),
#  ('Raleigh                                           ', 'Billing Question    ', 111),
#  ('Lexington                                         ', 'Billing Question    ', 110),
#  ('Fort Lauderdale                                   ', 'Billing Question    ', 109),
#  ('Milwaukee                                         ', 'Billing Question    ', 109),
#  ('Fort Wayne                                        ', 'Billing Question    ', 108),
#  ('Brooklyn                                          ', 'Billing Question    ', 107),
#  ('Honolulu                                          ', 'Billing Question    ', 107),
#  ('Baton Rouge                                       ', 'Billing Question    ', 106),
#  ('Cleveland                                         ', 'Billing Question    ', 104),
#  ('Pasadena                                          ', 'Billing Question    ', 103),
#  ('Amarillo                                          ', 'Billing Question    ', 101),
#  ('Omaha                                             ', 'Billing Question    ', 98),
#  ('Boise                                             ', 'Billing Question    ', 95),
#  ('Evansville                                        ', 'Billing Question    ', 92),
#  ('Houston                                           ', 'Payments            ', 90),
#  ('Tacoma                                            ', 'Billing Question    ', 90),
#  ('Knoxville                                         ', 'Billing Question    ', 89),
#  ('Columbia                                          ', 'Billing Question    ', 89),
#  ('Wichita                                           ', 'Billing Question    ', 88),
#  ('Jamaica                                           ', 'Billing Question    ', 88),
#  ('Buffalo                                           ', 'Billing Question    ', 86),
#  ('Greensboro                                        ', 'Billing Question    ', 85),
#  ('Shawnee Mission                                   ', 'Billing Question    ', 85),
#  ('Wilmington                                        ', 'Billing Question    ', 84),
#  ('Peoria                                            ', 'Billing Question    ', 84),
#  ('El Paso                                           ', 'Service Outage      ', 84),
#  ('Corpus Christi                                    ', 'Billing Question    ', 84),
#  ('Madison                                           ', 'Billing Question    ', 83),
#  ('Hartford                                          ', 'Billing Question    ', 83),
#  ('New York City                                     ', 'Payments            ', 83),
#  ('Akron                                             ', 'Billing Question    ', 82),
#  ('Toledo                                            ', 'Billing Question    ', 82),
#  ('Little Rock                                       ', 'Billing Question    ', 82),
#  ('Huntington                                        ', 'Billing Question    ', 81),
#  ('Pensacola                                         ', 'Billing Question    ', 81),
#  ('Spokane                                           ', 'Billing Question    ', 80),
#  ('Saint Petersburg                                  ', 'Billing Question    ', 80),
#  ('Lincoln                                           ', 'Billing Question    ', 77),
#  ('Shreveport                                        ', 'Billing Question    ', 77),
#  ('Newark                                            ', 'Billing Question    ', 76),
#  ('New York City                                     ', 'Service Outage      ', 74),
#  ('Erie                                              ', 'Billing Question    ', 74),
#  ('Clearwater                                        ', 'Billing Question    ', 73),
#  ('Trenton                                           ', 'Billing Question    ', 73),
#  ('Houston                                           ', 'Service Outage      ', 73),
#  ('Oakland                                           ', 'Billing Question    ', 72),
#  ('Jackson                                           ', 'Billing Question    ', 71),
#  ('El Paso                                           ', 'Payments            ', 70),
#  ('Syracuse                                          ', 'Billing Question    ', 69),
#  ('West Palm Beach                                   ', 'Billing Question    ', 69),
#  ('Bakersfield                                       ', 'Billing Question    ', 67),
#  ('Huntsville                                        ', 'Billing Question    ', 67),
#  ('Reno                                              ', 'Billing Question    ', 66),
#  ('Bronx                                             ', 'Billing Question    ', 65),
#  ('Tallahassee                                       ', 'Billing Question    ', 64),
#  ('Dallas                                            ', 'Service Outage      ', 64),
#  ('Long Beach                                        ', 'Billing Question    ', 62),
#  ('Alexandria                                        ', 'Billing Question    ', 62),
#  ('Grand Rapids                                      ', 'Billing Question    ', 62),
#  ('Lansing                                           ', 'Billing Question    ', 61),
#  ('Sioux Falls                                       ', 'Billing Question    ', 61),
#  ('Atlanta                                           ', 'Service Outage      ', 61),
#  ('Dallas                                            ', 'Payments            ', 61),
#  ('Miami                                             ', 'Payments            ', 60),
#  ('Atlanta                                           ', 'Payments            ', 60),
#  ('Sacramento                                        ', 'Payments            ', 59),
#  ('South Bend                                        ', 'Billing Question    ', 58),
#  ('Glendale                                          ', 'Billing Question    ', 56),
#  ('Anchorage                                         ', 'Billing Question    ', 56),
#  ('Sacramento                                        ', 'Service Outage      ', 56),
#  ('Miami                                             ', 'Service Outage      ', 55),
#  ('New Haven                                         ', 'Billing Question    ', 54),
#  ('Naples                                            ', 'Billing Question    ', 54),
#  ('Norfolk                                           ', 'Billing Question    ', 54),
#  ('Pittsburgh                                        ', 'Service Outage      ', 53),
#  ('Savannah                                          ', 'Billing Question    ', 53),
#  ('Harrisburg                                        ', 'Billing Question    ', 53),
#  ('Chicago                                           ', 'Payments            ', 52),
#  ('Aurora                                            ', 'Billing Question    ', 52),
#  ('Irvine                                            ', 'Billing Question    ', 52),
#  ('Chicago                                           ', 'Service Outage      ', 51),
#  ('Flint                                             ', 'Billing Question    ', 51),
#  ('Winston Salem                                     ', 'Billing Question    ', 51),
#  ('Stockton                                          ', 'Billing Question    ', 50),
#  ('Chattanooga                                       ', 'Billing Question    ', 50),
#  ('Kansas City                                       ', 'Service Outage      ', 49),
#  ('Gainesville                                       ', 'Billing Question    ', 49),
#  ('Springfield                                       ', 'Payments            ', 49),
#  ('Denver                                            ', 'Payments            ', 48),
#  ('Orange                                            ', 'Billing Question    ', 48),
#  ('Philadelphia                                      ', 'Service Outage      ', 48),
#  ('Kansas City                                       ', 'Payments            ', 47),
#  ('Young America                                     ', 'Billing Question    ', 47),
#  ('San Antonio                                       ', 'Service Outage      ', 46),
#  ('Lubbock                                           ', 'Billing Question    ', 46),
#  ('Durham                                            ', 'Billing Question    ', 45),
#  ('Austin                                            ', 'Payments            ', 45),
#  ('Mesa                                              ', 'Billing Question    ', 45),
#  ('Virginia Beach                                    ', 'Billing Question    ', 44),
#  ('Riverside                                         ', 'Billing Question    ', 44),
#  ('Los Angeles                                       ', 'Service Outage      ', 44),
#  ('Phoenix                                           ', 'Payments            ', 44),
#  ('Los Angeles                                       ', 'Payments            ', 44),
#  ('Van Nuys                                          ', 'Billing Question    ', 44),
#  ('Pueblo                                            ', 'Billing Question    ', 44),
#  ('Inglewood                                         ', 'Billing Question    ', 43),
#  ('San Bernardino                                    ', 'Billing Question    ', 43),
#  ('Wilkes Barre                                      ', 'Billing Question    ', 43),
#  ('Daytona Beach                                     ', 'Billing Question    ', 42),
#  ('Augusta                                           ', 'Billing Question    ', 42),
#  ('Cincinnati                                        ', 'Payments            ', 42),
#  ('Richmond                                          ', 'Service Outage      ', 42),
#  ('Monticello                                        ', 'Billing Question    ', 42),
#  ('Scottsdale                                        ', 'Billing Question    ', 41),
#  ('Anaheim                                           ', 'Billing Question    ', 41),
#  ('Tyler                                             ', 'Billing Question    ', 41),
#  ('Phoenix                                           ', 'Service Outage      ', 41),
#  ('Minneapolis                                       ', 'Service Outage      ', 40),
#  ('Fresno                                            ', 'Service Outage      ', 40),
#  ('Bradenton                                         ', 'Billing Question    ', 40),
#  ('Las Vegas                                         ', 'Service Outage      ', 40),
#  ('Philadelphia                                      ', 'Payments            ', 40),
#  ('Austin                                            ', 'Service Outage      ', 40),
#  ('Pittsburgh                                        ', 'Payments            ', 40),
#  ('San Diego                                         ', 'Payments            ', 40),
#  ('Midland                                           ', 'Billing Question    ', 39),
#  ('Lancaster                                         ', 'Billing Question    ', 39),
#  ('Birmingham                                        ', 'Payments            ', 39),
#  ('Birmingham                                        ', 'Service Outage      ', 39),
#  ('Billings                                          ', 'Billing Question    ', 38),
#  ('Tulsa                                             ', 'Service Outage      ', 38),
#  ('San Diego                                         ', 'Service Outage      ', 38),
#  ('Silver Spring                                     ', 'Billing Question    ', 38),
#  ('Youngstown                                        ', 'Billing Question    ', 38),
#  ('Macon                                             ', 'Billing Question    ', 38),
#  ('Duluth                                            ', 'Billing Question    ', 38),
#  ('Oklahoma City                                     ', 'Payments            ', 38),
#  ('Salt Lake City                                    ', 'Service Outage      ', 37),
#  ('Charlotte                                         ', 'Service Outage      ', 37),
#  ('Cincinnati                                        ', 'Service Outage      ', 37),
#  ('Charleston                                        ', 'Service Outage      ', 37),
#  ('Memphis                                           ', 'Payments            ', 37),
#  ('San Francisco                                     ', 'Service Outage      ', 37),
#  ('Fort Myers                                        ', 'Billing Question    ', 37),
#  ('Charlotte                                         ', 'Payments            ', 37),
#  ('Saint Louis                                       ', 'Service Outage      ', 37),
#  ('Santa Barbara                                     ', 'Billing Question    ', 37),
#  ('Irving                                            ', 'Billing Question    ', 37),
#  ('Boca Raton                                        ', 'Billing Question    ', 37),
#  ('Springfield                                       ', 'Service Outage      ', 36),
#  ('Colorado Springs                                  ', 'Payments            ', 36),
#  ('Indianapolis                                      ', 'Payments            ', 36),
#  ('Orlando                                           ', 'Service Outage      ', 36),
#  ('Portsmouth                                        ', 'Billing Question    ', 36),
#  ('San Antonio                                       ', 'Payments            ', 36),
#  ('Paterson                                          ', 'Billing Question    ', 36),
#  ('Waco                                              ', 'Billing Question    ', 36),
#  ('Lake Worth                                        ', 'Billing Question    ', 35),
#  ('Des Moines                                        ', 'Payments            ', 35),
#  ('Memphis                                           ', 'Service Outage      ', 35),
#  ('Boulder                                           ', 'Billing Question    ', 35),
#  ('Detroit                                           ', 'Service Outage      ', 35),
#  ('Tulsa                                             ', 'Payments            ', 34),
#  ('Peoria                                            ', 'Payments            ', 34),
#  ('Oklahoma City                                     ', 'Service Outage      ', 34),
#  ('Richmond                                          ', 'Payments            ', 34),
#  ('Corona                                            ', 'Billing Question    ', 34),
#  ('Saint Cloud                                       ', 'Billing Question    ', 34),
#  ('Saint Louis                                       ', 'Payments            ', 34),
#  ('Omaha                                             ', 'Payments            ', 33),
#  ('Worcester                                         ', 'Billing Question    ', 33),
#  ('Berkeley                                          ', 'Billing Question    ', 33),
#  ('Louisville                                        ', 'Payments            ', 33),
#  ('Littleton                                         ', 'Billing Question    ', 33),
#  ('Sarasota                                          ', 'Billing Question    ', 33),
#  ('Canton                                            ', 'Billing Question    ', 33),
#  ('Green Bay                                         ', 'Billing Question    ', 32),
#  ('Stamford                                          ', 'Billing Question    ', 32),
#  ('Pompano Beach                                     ', 'Billing Question    ', 32),
#  ('Fresno                                            ', 'Payments            ', 32),
#  ('Waterbury                                         ', 'Billing Question    ', 32),
#  ('Davenport                                         ', 'Billing Question    ', 32),
#  ('Decatur                                           ', 'Billing Question    ', 32),
#  ('Minneapolis                                       ', 'Payments            ', 32),
#  ('Lakeland                                          ', 'Billing Question    ', 32),
#  ('Spartanburg                                       ', 'Billing Question    ', 31),
#  ('Vero Beach                                        ', 'Billing Question    ', 31),
#  ('Jacksonville                                      ', 'Payments            ', 31),
#  ('Portland                                          ', 'Payments            ', 31),
#  ('Indianapolis                                      ', 'Service Outage      ', 31),
#  ('Portland                                          ', 'Service Outage      ', 31),
#  ('Boston                                            ', 'Service Outage      ', 31),
#  ('Hollywood                                         ', 'Billing Question    ', 31),
#  ('Jefferson City                                    ', 'Billing Question    ', 30),
#  ('Charleston                                        ', 'Payments            ', 30),
#  ('Arlington                                         ', 'Service Outage      ', 30),
#  ('Newton                                            ', 'Billing Question    ', 30),
#  ('Columbus                                          ', 'Service Outage      ', 30),
#  ('Albany                                            ', 'Service Outage      ', 30),
#  ('San Francisco                                     ', 'Payments            ', 30),
#  ('Columbus                                          ', 'Payments            ', 30),
#  ('Tucson                                            ', 'Service Outage      ', 30),
#  ('Tampa                                             ', 'Payments            ', 30),
#  ('Las Vegas                                         ', 'Payments            ', 30),
#  ('Ocala                                             ', 'Billing Question    ', 30),
#  ('Salt Lake City                                    ', 'Payments            ', 29),
#  ('Albany                                            ', 'Payments            ', 29),
#  ('Vancouver                                         ', 'Billing Question    ', 29),
#  ('Tucson                                            ', 'Payments            ', 29),
#  ('Des Moines                                        ', 'Service Outage      ', 29),
#  ('Fort Lauderdale                                   ', 'Service Outage      ', 29),
#  ('Buffalo                                           ', 'Service Outage      ', 29),
#  ('Lawrenceville                                     ', 'Billing Question    ', 29),
#  ('Cedar Rapids                                      ', 'Billing Question    ', 29),
#  ('Staten Island                                     ', 'Billing Question    ', 29),
#  ('Newport News                                      ', 'Billing Question    ', 29),
#  ('Rochester                                         ', 'Payments            ', 29),
#  ('White Plains                                      ', 'Billing Question    ', 29),
#  ('Fort Worth                                        ', 'Payments            ', 29),
#  ('Schenectady                                       ', 'Billing Question    ', 28),
#  ('Saint Paul                                        ', 'Payments            ', 28),
#  ('Garden Grove                                      ', 'Billing Question    ', 28),
#  ('Beaumont                                          ', 'Billing Question    ', 28),
#  ('Pasadena                                          ', 'Service Outage      ', 28),
#  ('New Orleans                                       ', 'Payments            ', 28),
#  ('Carson City                                       ', 'Billing Question    ', 28),
#  ('Rockford                                          ', 'Billing Question    ', 28),
#  ('Fort Smith                                        ', 'Billing Question    ', 28),
#  ('Louisville                                        ', 'Service Outage      ', 28),
#  ('Modesto                                           ', 'Billing Question    ', 28),
#  ('Flushing                                          ', 'Billing Question    ', 27),
#  ('Saint Paul                                        ', 'Service Outage      ', 27),
#  ('Providence                                        ', 'Billing Question    ', 27),
#  ('San Jose                                          ', 'Service Outage      ', 27),
#  ('Seattle                                           ', 'Service Outage      ', 27),
#  ('Orlando                                           ', 'Payments            ', 27),
#  ('Santa Ana                                         ', 'Billing Question    ', 27),
#  ('Greenville                                        ', 'Billing Question    ', 27),
#  ('Baltimore                                         ', 'Service Outage      ', 27),
#  ('Brockton                                          ', 'Billing Question    ', 27),
#  ('Jacksonville                                      ', 'Service Outage      ', 27),
#  ('Bethesda                                          ', 'Billing Question    ', 27),
#  ('Santa Fe                                          ', 'Billing Question    ', 27),
#  ('Largo                                             ', 'Billing Question    ', 26),
#  ('Arlington                                         ', 'Payments            ', 26),
#  ('Burbank                                           ', 'Billing Question    ', 26),
#  ('Cleveland                                         ', 'Service Outage      ', 26),
#  ('Montgomery                                        ', 'Payments            ', 26),
#  ('Denver                                            ', 'Service Outage      ', 26),
#  ('Lake Charles                                      ', 'Billing Question    ', 26),
#  ('Reading                                           ', 'Billing Question    ', 26),
#  ('Albuquerque                                       ', 'Service Outage      ', 26),
#  ('Colorado Springs                                  ', 'Service Outage      ', 26),
#  ('Seattle                                           ', 'Payments            ', 26),
#  ('Amarillo                                          ', 'Payments            ', 26),
#  ('Fort Wayne                                        ', 'Payments            ', 26),
#  ('Sioux City                                        ', 'Billing Question    ', 25),
#  ('North Little Rock                                 ', 'Billing Question    ', 25),
#  ('Carol Stream                                      ', 'Billing Question    ', 25),
#  ('North Hollywood                                   ', 'Billing Question    ', 25),
#  ('Saint Petersburg                                  ', 'Payments            ', 25),
#  ('Brooklyn                                          ', 'Payments            ', 25),
#  ('Fort Worth                                        ', 'Service Outage      ', 25),
#  ('Shawnee Mission                                   ', 'Payments            ', 25),
#  ('Wichita Falls                                     ', 'Billing Question    ', 25),
#  ('Fairbanks                                         ', 'Billing Question    ', 25),
#  ('Dayton                                            ', 'Service Outage      ', 25),
#  ('Huntington                                        ', 'Service Outage      ', 25),
#  ('Denton                                            ', 'Billing Question    ', 25),
#  ('Henderson                                         ', 'Billing Question    ', 25),
#  ('Alhambra                                          ', 'Billing Question    ', 25),
#  ('Tampa                                             ', 'Service Outage      ', 25),
#  ('Melbourne                                         ', 'Billing Question    ', 24),
#  ('Amarillo                                          ', 'Service Outage      ', 24),
#  ('Charlottesville                                   ', 'Billing Question    ', 24),
#  ('Terre Haute                                       ', 'Billing Question    ', 24),
#  ('Lynchburg                                         ', 'Billing Question    ', 24),
#  ('Salem                                             ', 'Billing Question    ', 24),
#  ('Odessa                                            ', 'Billing Question    ', 24),
#  ('Asheville                                         ', 'Billing Question    ', 24),
#  ('Lafayette                                         ', 'Billing Question    ', 24),
#  ('Honolulu                                          ', 'Payments            ', 23),
#  ('Hampton                                           ', 'Billing Question    ', 23),
#  ('Abilene                                           ', 'Billing Question    ', 23),
#  ('Jamaica                                           ', 'Service Outage      ', 23),
#  ('Fort Lauderdale                                   ', 'Payments            ', 23),
#  ('Boston                                            ', 'Payments            ', 23),
#  ('Jersey City                                       ', 'Billing Question    ', 23),
#  ('Monroe                                            ', 'Billing Question    ', 23),
#  ('Kalamazoo                                         ', 'Billing Question    ', 23),
#  ('San Jose                                          ', 'Payments            ', 23),
#  ('Tacoma                                            ', 'Service Outage      ', 23),
#  ('Tuscaloosa                                        ', 'Billing Question    ', 23),
#  ('Torrance                                          ', 'Billing Question    ', 23),
#  ('Dayton                                            ', 'Payments            ', 23),
#  ('Shreveport                                        ', 'Service Outage      ', 23),
#  ('Ogden                                             ', 'Billing Question    ', 22),
#  ('Milwaukee                                         ', 'Service Outage      ', 22),
#  ('Boise                                             ', 'Payments            ', 22),
#  ('Cleveland                                         ', 'Payments            ', 22),
#  ('Baltimore                                         ', 'Payments            ', 22),
#  ('Fort Pierce                                       ', 'Billing Question    ', 22),
#  ('Anderson                                          ', 'Billing Question    ', 22),
#  ('Roanoke                                           ', 'Payments            ', 22),
#  ('Huntington                                        ', 'Payments            ', 22),
#  ('Reston                                            ', 'Billing Question    ', 22),
#  ('Montgomery                                        ', 'Service Outage      ', 22),
#  ('Baton Rouge                                       ', 'Payments            ', 21),
#  ('Olympia                                           ', 'Billing Question    ', 21),
#  ('Norcross                                          ', 'Billing Question    ', 21),
#  ('Wichita                                           ', 'Service Outage      ', 21),
#  ('Roanoke                                           ', 'Service Outage      ', 21),
#  ('Bloomington                                       ', 'Billing Question    ', 21),
#  ('Pensacola                                         ', 'Payments            ', 21),
#  ('Topeka                                            ', 'Service Outage      ', 21),
#  ('Panama City                                       ', 'Billing Question    ', 21),
#  ('Nashville                                         ', 'Service Outage      ', 21),
#  ('Saginaw                                           ', 'Billing Question    ', 21),
#  ('Warren                                            ', 'Billing Question    ', 21),
#  ('Topeka                                            ', 'Payments            ', 21),
#  ('Metairie                                          ', 'Billing Question    ', 21),
#  ('Jamaica                                           ', 'Payments            ', 21),
#  ('San Mateo                                         ', 'Billing Question    ', 21),
#  ('Mansfield                                         ', 'Billing Question    ', 21),
#  ('Peoria                                            ', 'Service Outage      ', 21),
#  ('Santa Monica                                      ', 'Billing Question    ', 21),
#  ('Marietta                                          ', 'Billing Question    ', 21),
#  ('Corpus Christi                                    ', 'Service Outage      ', 21),
#  ('Lexington                                         ', 'Payments            ', 21),
#  ('Wilmington                                        ', 'Payments            ', 21),
#  ('Nashville                                         ', 'Payments            ', 21),
#  ('Scranton                                          ', 'Billing Question    ', 21),
#  ('Bronx                                             ', 'Service Outage      ', 20),
#  ('Toledo                                            ', 'Service Outage      ', 20),
#  ('Hattiesburg                                       ', 'Billing Question    ', 20),
#  ('Grand Forks                                       ', 'Billing Question    ', 20),
#  ('Jackson                                           ', 'Payments            ', 20),
#  ('Spring                                            ', 'Billing Question    ', 20),
#  ('Fairfax                                           ', 'Billing Question    ', 20),
#  ('Bridgeport                                        ', 'Billing Question    ', 20),
#  ('Fargo                                             ', 'Billing Question    ', 20),
#  ('Bismarck                                          ', 'Billing Question    ', 20),
#  ('New Orleans                                       ', 'Service Outage      ', 20),
#  ('Vienna                                            ', 'Billing Question    ', 20),
#  ('Baton Rouge                                       ', 'Service Outage      ', 20),
#  ('Pasadena                                          ', 'Payments            ', 20),
#  ('Anchorage                                         ', 'Service Outage      ', 19),
#  ('Hialeah                                           ', 'Billing Question    ', 19),
#  ('Fullerton                                         ', 'Billing Question    ', 19),
#  ('Omaha                                             ', 'Service Outage      ', 19),
#  ('Mobile                                            ', 'Payments            ', 19),
#  ('Albuquerque                                       ', 'Payments            ', 19),
#  ('Honolulu                                          ', 'Service Outage      ', 19),
#  ('Joliet                                            ', 'Billing Question    ', 19),
#  ('Conroe                                            ', 'Billing Question    ', 19),
#  ('Saint Petersburg                                  ', 'Service Outage      ', 19),
#  ('Evansville                                        ', 'Service Outage      ', 19),
#  ('Brooklyn                                          ', 'Service Outage      ', 19),
#  ('Corpus Christi                                    ', 'Payments            ', 19),
#  ('Madison                                           ', 'Payments            ', 19),
#  ('Elmira                                            ', 'Billing Question    ', 19),
#  ('Mobile                                            ', 'Service Outage      ', 19),
#  ('Huntington Beach                                  ', 'Billing Question    ', 19),
#  ('Raleigh                                           ', 'Service Outage      ', 19),
#  ('Bellevue                                          ', 'Billing Question    ', 19),
#  ('Sioux Falls                                       ', 'Payments            ', 18),
#  ('North Las Vegas                                   ', 'Billing Question    ', 18),
#  ('Harrisburg                                        ', 'Payments            ', 18),
#  ('Chesapeake                                        ', 'Billing Question    ', 18),
#  ('East Saint Louis                                  ', 'Billing Question    ', 18),
#  ('Maple Plain                                       ', 'Billing Question    ', 18),
#  ('Palo Alto                                         ', 'Billing Question    ', 18),
#  ('Norwalk                                           ', 'Billing Question    ', 18),
#  ('Pensacola                                         ', 'Service Outage      ', 18),
#  ('Shreveport                                        ', 'Payments            ', 18),
#  ('Bakersfield                                       ', 'Service Outage      ', 18),
#  ('Trenton                                           ', 'Service Outage      ', 18),
#  ('Fayetteville                                      ', 'Billing Question    ', 18),
#  ('Cape Coral                                        ', 'Billing Question    ', 18),
#  ('San Luis Obispo                                   ', 'Billing Question    ', 18),
#  ('Round Rock                                        ', 'Billing Question    ', 17),
#  ('Northridge                                        ', 'Billing Question    ', 17),
#  ('Visalia                                           ', 'Billing Question    ', 17),
#  ('Provo                                             ', 'Billing Question    ', 17),
#  ('Buffalo                                           ', 'Payments            ', 17),
#  ('Brea                                              ', 'Billing Question    ', 17),
#  ('Rochester                                         ', 'Service Outage      ', 17),
#  ('Spokane                                           ', 'Service Outage      ', 17),
#  ('Bowie                                             ', 'Billing Question    ', 17),
#  ('Wichita                                           ', 'Payments            ', 17),
#  ('South Lake Tahoe                                  ', 'Billing Question    ', 17),
#  ('Macon                                             ', 'Service Outage      ', 17),
#  ('Spokane                                           ', 'Payments            ', 17),
#  ('New Haven                                         ', 'Payments            ', 17),
#  ('Toledo                                            ', 'Payments            ', 17),
#  ('Huntsville                                        ', 'Payments            ', 17),
#  ('Newark                                            ', 'Payments            ', 17),
#  ('Hot Springs National Park                         ', 'Billing Question    ', 17),
#  ('Whittier                                          ', 'Billing Question    ', 17),
#  ('Loretto                                           ', 'Billing Question    ', 17),
#  ('Chandler                                          ', 'Billing Question    ', 17),
#  ('College Station                                   ', 'Billing Question    ', 17),
#  ('Sunnyvale                                         ', 'Billing Question    ', 17),
#  ('Knoxville                                         ', 'Service Outage      ', 16),
#  ('Seminole                                          ', 'Billing Question    ', 16),
#  ('Laurel                                            ', 'Billing Question    ', 16),
#  ('Sparks                                            ', 'Billing Question    ', 16),
#  ('Wilmington                                        ', 'Service Outage      ', 16),
#  ('West Palm Beach                                   ', 'Payments            ', 16),
#  ('Hartford                                          ', 'Service Outage      ', 16),
#  ('San Bernardino                                    ', 'Payments            ', 16),
#  ('Oakland                                           ', 'Payments            ', 16),
#  ('Punta Gorda                                       ', 'Billing Question    ', 16),
#  ('San Angelo                                        ', 'Billing Question    ', 16),
#  ('Newport Beach                                     ', 'Billing Question    ', 16),
#  ('Mountain View                                     ', 'Billing Question    ', 16),
#  ('Raleigh                                           ', 'Payments            ', 16),
#  ('Bryan                                             ', 'Billing Question    ', 16),
#  ('Madison                                           ', 'Service Outage      ', 16),
#  ('Greensboro                                        ', 'Payments            ', 16),
#  ('Evansville                                        ', 'Payments            ', 16),
#  ('Lakewood                                          ', 'Billing Question    ', 16),
#  ('Prescott                                          ', 'Billing Question    ', 16),
#  ('Palatine                                          ', 'Billing Question    ', 16),
#  ('Anchorage                                         ', 'Payments            ', 16),
#  ('Oakland                                           ', 'Service Outage      ', 16),
#  ('London                                            ', 'Billing Question    ', 16),
#  ('Erie                                              ', 'Service Outage      ', 16),
#  ('Plano                                             ', 'Billing Question    ', 16),
#  ('Boise                                             ', 'Service Outage      ', 16),
#  ('Little Rock                                       ', 'Payments            ', 16),
#  ('Oceanside                                         ', 'Billing Question    ', 15),
#  ('Anniston                                          ', 'Billing Question    ', 15),
#  ('Independence                                      ', 'Billing Question    ', 15),
#  ('Winston Salem                                     ', 'Payments            ', 15),
#  ('Hartford                                          ', 'Payments            ', 15),
#  ('Pocatello                                         ', 'Billing Question    ', 15),
#  ('Moreno Valley                                     ', 'Billing Question    ', 15),
#  ('Tacoma                                            ', 'Payments            ', 15),
#  ('Irvine                                            ', 'Service Outage      ', 15),
#  ('Suffolk                                           ', 'Billing Question    ', 15),
#  ('Spring Hill                                       ', 'Billing Question    ', 15),
#  ('Muncie                                            ', 'Billing Question    ', 15),
#  ('Durham                                            ', 'Payments            ', 15),
#  ('Ventura                                           ', 'Billing Question    ', 15),
#  ('Saint Joseph                                      ', 'Billing Question    ', 15),
#  ('Detroit                                           ', 'Payments            ', 15),
#  ('Biloxi                                            ', 'Billing Question    ', 15),
#  ('Farmington                                        ', 'Billing Question    ', 15),
#  ('Winter Haven                                      ', 'Billing Question    ', 15),
#  ('Appleton                                          ', 'Billing Question    ', 15),
#  ('Naperville                                        ', 'Billing Question    ', 15),
#  ('Everett                                           ', 'Billing Question    ', 15),
#  ('Athens                                            ', 'Billing Question    ', 15),
#  ('Knoxville                                         ', 'Payments            ', 15),
#  ('Reno                                              ', 'Service Outage      ', 15),
#  ('Clearwater                                        ', 'Payments            ', 15),
#  ('Huntsville                                        ', 'Service Outage      ', 14),
#  ('Chattanooga                                       ', 'Service Outage      ', 14),
#  ('Trenton                                           ', 'Payments            ', 14),
#  ('Sioux Falls                                       ', 'Service Outage      ', 14),
#  ('Long Beach                                        ', 'Service Outage      ', 14),
#  ('Santa Clara                                       ', 'Billing Question    ', 14),
#  ('Schaumburg                                        ', 'Billing Question    ', 14),
#  ('Delray Beach                                      ', 'Billing Question    ', 14),
#  ('Shawnee Mission                                   ', 'Service Outage      ', 14),
#  ('Las Cruces                                        ', 'Billing Question    ', 14),
#  ('Hyattsville                                       ', 'Billing Question    ', 14),
#  ('Bakersfield                                       ', 'Payments            ', 14),
#  ('Manchester                                        ', 'Billing Question    ', 14),
#  ('Lexington                                         ', 'Service Outage      ', 14),
#  ('Milwaukee                                         ', 'Payments            ', 14),
#  ('Galveston                                         ', 'Billing Question    ', 14),
#  ('Naples                                            ', 'Payments            ', 14),
#  ('Idaho Falls                                       ', 'Billing Question    ', 14),
#  ('Merrifield                                        ', 'Billing Question    ', 14),
#  ('Bozeman                                           ', 'Billing Question    ', 14),
#  ('Columbia                                          ', 'Payments            ', 14),
#  ('Miami Beach                                       ', 'Billing Question    ', 14),
#  ('Meridian                                          ', 'Billing Question    ', 14),
#  ('Norman                                            ', 'Billing Question    ', 13),
#  ('Dulles                                            ', 'Billing Question    ', 13),
#  ('York                                              ', 'Billing Question    ', 13),
#  ('Santa Cruz                                        ', 'Billing Question    ', 13),
#  ('Canton                                            ', 'Service Outage      ', 13),
#  ('Alexandria                                        ', 'Service Outage      ', 13),
#  ('Bronx                                             ', 'Payments            ', 13),
#  ('Tempe                                             ', 'Billing Question    ', 13),
#  ('Johnson City                                      ', 'Billing Question    ', 13),
#  ('Ashburn                                           ', 'Billing Question    ', 13),
#  ('Duluth                                            ', 'Service Outage      ', 13),
#  ('Humble                                            ', 'Billing Question    ', 13),
#  ('Gilbert                                           ', 'Billing Question    ', 13),
#  ('Redwood City                                      ', 'Billing Question    ', 13),
#  ('Mesa                                              ', 'Payments            ', 13),
#  ('Escondido                                         ', 'Billing Question    ', 13),
#  ('Erie                                              ', 'Payments            ', 13),
#  ('New Castle                                        ', 'Billing Question    ', 13),
#  ('Bonita Springs                                    ', 'Billing Question    ', 13),
#  ('Paterson                                          ', 'Service Outage      ', 13),
# ...
#  ('Bonita Springs                                    ', 'Payments            ', 6),
#  ('New Brunswick                                     ', 'Payments            ', 6),
#  ('Cedar Rapids                                      ', 'Service Outage      ', 6),
#  ('Orange                                            ', 'Service Outage      ', 6),
#  ('Cheyenne                                          ', 'Billing Question    ', 6),
#  ('Spring                                            ', 'Payments            ', 6),
#  ('Port Charlotte                                    ', 'Billing Question    ', 6),
#  ('Port Washington                                   ', 'Payments            ', 6),
#  ('Elizabeth                                         ', 'Billing Question    ', 6),
#  ('Hot Springs National Park                         ', 'Payments            ', 6),
#  ('Racine                                            ', 'Payments            ', 6),
#  ('Hialeah                                           ', 'Service Outage      ', 6),
#  ('Wichita Falls                                     ', 'Payments            ', 6),
#  ('Savannah                                          ', 'Service Outage      ', 6),
#  ('Silver Spring                                     ', 'Payments            ', 6),
#  ('Beaumont                                          ', 'Payments            ', 6),
#  ('Burbank                                           ', 'Payments            ', 6),
#  ('Lafayette                                         ', 'Payments            ', 6),
#  ('East Saint Louis                                  ', 'Payments            ', 6),
#  ('Melbourne                                         ', 'Payments            ', 6),
#  ('Newport News                                      ', 'Service Outage      ', 6),
#  ('Morgantown                                        ', 'Service Outage      ', 6),
#  ('Daytona Beach                                     ', 'Service Outage      ', 6),
#  ('Santa Ana                                         ', 'Service Outage      ', 6),
#  ('Crawfordsville                                    ', 'Billing Question    ', 6),
#  ('Providence                                        ', 'Payments            ', 6),
#  ('Staten Island                                     ', 'Service Outage      ', 6),
#  ('Fullerton                                         ', 'Service Outage      ', 6),
#  ('Canton                                            ', 'Payments            ', 6),
#  ('Saint Joseph                                      ', 'Service Outage      ', 6),
#  ('Worcester                                         ', 'Payments            ', 6),
#  ('Kingsport                                         ', 'Billing Question    ', 6),
#  ('Fredericksburg                                    ', 'Service Outage      ', 6),
#  ('Warren                                            ', 'Payments            ', 6),
#  ('Bridgeport                                        ', 'Payments            ', 6),
#  ('Schenectady                                       ', 'Service Outage      ', 6),
#  ('Alexandria                                        ', 'Payments            ', 6),
#  ('Carol Stream                                      ', 'Payments            ', 6),
#  ('Boca Raton                                        ', 'Payments            ', 6),
#  ('Eugene                                            ', 'Billing Question    ', 6),
#  ('North Hollywood                                   ', 'Service Outage      ', 6),
#  ('Santa Barbara                                     ', 'Service Outage      ', 6),
#  ('Danbury                                           ', 'Payments            ', 6),
#  ('Huntington Beach                                  ', 'Service Outage      ', 6),
#  ('Lawrenceville                                     ', 'Service Outage      ', 6),
#  ('Saint Cloud                                       ', 'Payments            ', 6),
#  ('Pueblo                                            ', 'Service Outage      ', 6),
#  ('Jefferson City                                    ', 'Service Outage      ', 6),
#  ('San Luis Obispo                                   ', 'Service Outage      ', 6),
#  ('Panama City                                       ', 'Service Outage      ', 6),
#  ('Monticello                                        ', 'Service Outage      ', 6),
#  ('Terre Haute                                       ', 'Payments            ', 6),
#  ('Bridgeport                                        ', 'Service Outage      ', 6),
#  ('Wilkes Barre                                      ', 'Payments            ', 6),
#  ('Provo                                             ', 'Payments            ', 6),
#  ('Green Bay                                         ', 'Payments            ', 6),
#  ('Fort Myers                                        ', 'Payments            ', 6),
#  ('Hamilton                                          ', 'Payments            ', 6),
#  ('Manchester                                        ', 'Service Outage      ', 5),
#  ('Beaverton                                         ', 'Service Outage      ', 5),
#  ('Chandler                                          ', 'Service Outage      ', 5),
#  ('Bradenton                                         ', 'Payments            ', 5),
#  ('Corona                                            ', 'Payments            ', 5),
#  ('Lake Worth                                        ', 'Payments            ', 5),
#  ('Lynchburg                                         ', 'Payments            ', 5),
#  ('Carol Stream                                      ', 'Service Outage      ', 5),
#  ('Athens                                            ', 'Payments            ', 5),
#  ('Reston                                            ', 'Payments            ', 5),
#  ('Saint Augustine                                   ', 'Payments            ', 5),
#  ('Fairbanks                                         ', 'Service Outage      ', 5),
#  ('Beaufort                                          ', 'Payments            ', 5),
#  ('Escondido                                         ', 'Service Outage      ', 5),
#  ('Elizabeth                                         ', 'Service Outage      ', 5),
#  ('Hollywood                                         ', 'Service Outage      ', 5),
#  ('Reading                                           ', 'Payments            ', 5),
#  ('Tuscaloosa                                        ', 'Payments            ', 5),
#  ('Monroe                                            ', 'Payments            ', 5),
#  ('Beaumont                                          ', 'Service Outage      ', 5),
#  ('Fort Pierce                                       ', 'Payments            ', 5),
#  ('Van Nuys                                          ', 'Service Outage      ', 5),
#  ('Northridge                                        ', 'Payments            ', 5),
#  ('Conroe                                            ', 'Service Outage      ', 5),
#  ('Cedar Rapids                                      ', 'Payments            ', 5),
#  ('Charlottesville                                   ', 'Service Outage      ', 5),
#  ('Fargo                                             ', 'Payments            ', 5),
#  ('Laurel                                            ', 'Service Outage      ', 5),
#  ('Abilene                                           ', 'Payments            ', 5),
#  ('Fort Collins                                      ', 'Service Outage      ', 5),
#  ('Lakeland                                          ', 'Service Outage      ', 5),
#  ('Lake Charles                                      ', 'Service Outage      ', 5),
#  ('Newport News                                      ', 'Payments            ', 5),
#  ('Jefferson City                                    ', 'Payments            ', 5),
#  ('Tempe                                             ', 'Payments            ', 5),
#  ('Grand Junction                                    ', 'Payments            ', 5),
#  ('Herndon                                           ', 'Payments            ', 5),
#  ('Abilene                                           ', 'Service Outage      ', 5),
#  ('College Station                                   ', 'Service Outage      ', 5),
#  ('Galveston                                         ', 'Payments            ', 5),
#  ('Denton                                            ', 'Payments            ', 5),
#  ('Frankfort                                         ', 'Service Outage      ', 5),
#  ('Salem                                             ', 'Service Outage      ', 5),
#  ('Woburn                                            ', 'Service Outage      ', 5),
#  ('Reno                                              ', 'Payments            ', 5),
#  ('Greenville                                        ', 'Payments            ', 5),
#  ('Lima                                              ', 'Service Outage      ', 5),
#  ('Johnson City                                      ', 'Payments            ', 5),
#  ('Sparks                                            ', 'Service Outage      ', 5),
#  ('Santa Rosa                                        ', 'Service Outage      ', 5),
#  ('Pinellas Park                                     ', 'Payments            ', 5),
#  ('Newton                                            ', 'Payments            ', 5),
#  ('Salem                                             ', 'Payments            ', 5),
#  ('Longview                                          ', 'Service Outage      ', 5),
#  ('Carson City                                       ', 'Service Outage      ', 5),
#  ('Burbank                                           ', 'Service Outage      ', 5),
#  ('Littleton                                         ', 'Service Outage      ', 5),
#  ('Hicksville                                        ', 'Payments            ', 5),
#  ('Ogden                                             ', 'Service Outage      ', 5),
#  ('Athens                                            ', 'Service Outage      ', 5),
#  ('Garland                                           ', 'Payments            ', 5),
#  ('Carlsbad                                          ', 'Service Outage      ', 5),
#  ('Delray Beach                                      ', 'Payments            ', 5),
#  ('Delray Beach                                      ', 'Service Outage      ', 5),
#  ('Anderson                                          ', 'Payments            ', 5),
#  ('Crawfordsville                                    ', 'Service Outage      ', 5),
#  ('Kalamazoo                                         ', 'Service Outage      ', 4),
#  ('Jersey City                                       ', 'Payments            ', 4),
#  ('Fullerton                                         ', 'Payments            ', 4),
#  ('Santa Fe                                          ', 'Payments            ', 4),
#  ('Hyattsville                                       ', 'Service Outage      ', 4),
#  ('Pompano Beach                                     ', 'Payments            ', 4),
#  ('Missoula                                          ', 'Service Outage      ', 4),
#  ('Scranton                                          ', 'Service Outage      ', 4),
#  ('Bethesda                                          ', 'Payments            ', 4),
#  ('Norcross                                          ', 'Service Outage      ', 4),
#  ('Fort Pierce                                       ', 'Service Outage      ', 4),
#  ('Allentown                                         ', 'Payments            ', 4),
#  ('Elmira                                            ', 'Payments            ', 4),
#  ('Fairfield                                         ', 'Payments            ', 4),
#  ('Falls Church                                      ', 'Service Outage      ', 4),
#  ('Riverside                                         ', 'Payments            ', 4),
#  ('Idaho Falls                                       ', 'Service Outage      ', 4),
#  ('Fairfax                                           ', 'Service Outage      ', 4),
#  ('Bryan                                             ', 'Service Outage      ', 4),
#  ('Pomona                                            ', 'Service Outage      ', 4),
#  ('Juneau                                            ', 'Service Outage      ', 4),
#  ('Spring Hill                                       ', 'Payments            ', 4),
#  ('Apache Junction                                   ', 'Payments            ', 4),
#  ('Seminole                                          ', 'Payments            ', 4),
#  ('Greenville                                        ', 'Service Outage      ', 4),
#  ('Concord                                           ', 'Payments            ', 4),
#  ('Berkeley                                          ', 'Service Outage      ', 4),
#  ('Round Rock                                        ', 'Payments            ', 4),
#  ('Carlsbad                                          ', 'Payments            ', 4),
#  ('Troy                                              ', 'Service Outage      ', 4),
#  ('Pompano Beach                                     ', 'Service Outage      ', 4),
#  ('Fredericksburg                                    ', 'Payments            ', 4),
#  ('Hialeah                                           ', 'Payments            ', 4),
#  ('Edmond                                            ', 'Billing Question    ', 4),
#  ('Edmond                                            ', 'Service Outage      ', 4),
#  ('Ocala                                             ', 'Service Outage      ', 4),
#  ('Bellevue                                          ', 'Service Outage      ', 4),
#  ('Ocala                                             ', 'Payments            ', 4),
#  ('Florence                                          ', 'Payments            ', 4),
#  ('Billings                                          ', 'Service Outage      ', 4),
#  ('Yonkers                                           ', 'Billing Question    ', 4),
#  ('Vero Beach                                        ', 'Service Outage      ', 4),
#  ('Kent                                              ', 'Payments            ', 4),
#  ('Scranton                                          ', 'Payments            ', 4),
#  ('Monroe                                            ', 'Service Outage      ', 4),
#  ('Homestead                                         ', 'Service Outage      ', 4),
#  ('Florence                                          ', 'Service Outage      ', 4),
#  ('Crawfordsville                                    ', 'Payments            ', 4),
#  ('Mountain View                                     ', 'Service Outage      ', 4),
#  ('Lakewood                                          ', 'Payments            ', 4),
#  ('Spring Hill                                       ', 'Service Outage      ', 4),
#  ('Cheyenne                                          ', 'Payments            ', 4),
#  ('Cumming                                           ', 'Payments            ', 4),
#  ('Port Charlotte                                    ', 'Payments            ', 4),
#  ('Modesto                                           ', 'Service Outage      ', 4),
#  ('London                                            ', 'Payments            ', 4),
#  ('Hampton                                           ', 'Payments            ', 4),
#  ('Torrance                                          ', 'Service Outage      ', 4),
#  ('Naperville                                        ', 'Service Outage      ', 4),
#  ('Gulfport                                          ', 'Payments            ', 4),
#  ('Garland                                           ', 'Service Outage      ', 4),
#  ('Iowa City                                         ', 'Payments            ', 4),
#  ('Jersey City                                       ', 'Service Outage      ', 4),
#  ('Waterloo                                          ', 'Service Outage      ', 4),
#  ('New Brunswick                                     ', 'Service Outage      ', 4),
#  ('Brockton                                          ', 'Payments            ', 4),
#  ...]

# %% [markdown]
# So from the previous question we got that Billing Question reason is the most reason over the calls. From the result above, we can see Washington is the city that have the most total calls over the Billing Question reason with 806 total calls. And also it happened in the other some city that Billing Question be the most reasons of the calls, such as Houston with 494 total calls, and New York City with 407 total calls.

# %% [markdown]
# ### 4. Which day has the most calls?

# %% [markdown]
# Next lets find out which day is the bussiest to receive the calls

# %%
# %%sql
#
# SELECT To_Char(call_timestamp, 'Day') as Day_of_call, COUNT(*) AS count_of_calls
# FROM calls GROUP BY Day_of_call ORDER BY count_of_calls DESC;
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 7 rows affected.
# [('Friday   ', 6546),
#  ('Thursday ', 5536),
#  ('Tuesday  ', 5432),
#  ('Wednesday', 4556),
#  ('Monday   ', 4307),
#  ('Saturday ', 3314),
#  ('Sunday   ', 3250)]

# %% [markdown]
# We get that Friday has the most calls with 6.548 total calls while sunday has the least with 3.250 total calls.

# %% [markdown]
# ### 5. Maximal, Minimal and the Average of the calls duration

# %% [markdown]
# Now we want to know how long is the maximum call duration, minimum call duration and average call duration. We can find the answer by using aggregate function.

# %%
# %%sql
#
# SELECT MAX (call_duration_minutes) AS max_call_duration_,
# MIN (call_duration_minutes) AS min_call_duration_,
# ROUND (AVG(call_duration_minutes),2) AS avg_call_duration_
# FROM calls;
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 1 rows affected.
# [(45, 5, Decimal('25.02'))]

# %% [markdown]
# By using the MAX, MIN, and AVG aggregate function, we have that the maximum call duration lasts in 45 minutes, minimum call duration in 5 minutes, and the average is 25.02 minutes.

# %% [markdown]
# ### 6. Response time by call centers

# %% [markdown]
# So the response time is the amount of time it takes from when the caller dials into the contact center, to the time they are connected with the appropriate agent.

# %%
# %%sql
#
# SELECT call_center, response_time, COUNT(*) AS count
# FROM calls GROUP BY call_center, response_time
# ORDER BY call_center, count DESC;
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 12 rows affected.
# [('Baltimore/MD        ', 'Within SLA          ', 6855),
#  ('Baltimore/MD        ', 'Below SLA           ', 2768),
#  ('Baltimore/MD        ', 'Above SLA           ', 1389),
#  ('Chicago/IL          ', 'Within SLA          ', 3361),
#  ('Chicago/IL          ', 'Below SLA           ', 1361),
#  ('Chicago/IL          ', 'Above SLA           ', 697),
#  ('Denver/CO           ', 'Within SLA          ', 1741),
#  ('Denver/CO           ', 'Below SLA           ', 692),
#  ('Denver/CO           ', 'Above SLA           ', 343),
#  ('Los Angeles/CA      ', 'Within SLA          ', 8668),
#  ('Los Angeles/CA      ', 'Below SLA           ', 3327),
#  ('Los Angeles/CA      ', 'Above SLA           ', 1739)]

# %% [markdown]
# A service level agreement (SLA) is a promise a contact center makes to provide a certain level of service to its clients. The most common SLA for a call center to make is committing to answering a percentage of inbound calls within a set time frame. From the result above, we can see how many calls are within, below and above the service level management time. For example Baltimore/MD call center has 6.855 calls within SLA, Chicago/IL call center has 1.361 calls below SLA, Denver/CO call center has 343 calls above SLA and Los Angeles/CA call center has 8.668 calls within SLA.

# %% [markdown]
# ### 7. How many channels?

# %% [markdown]
# Channels refer to the method or communication channel a customer uses to interact with a business.

# %%
# %%sql
#
# SELECT DISTINCT channel
# FROM calls;
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 4 rows affected.
# [('Chatbot             ',),
#  ('Web                 ',),
#  ('Email               ',),
#  ('Call-Center         ',)]

# %% [markdown]
# So we have 4 channels that customers use to interact with. Such as chatbot, web, email and call center.

# %% [markdown]
# ### 8. What is the most used channel by state?

# %% [markdown]
# So in our 'calls' database we have 'state' data field, we can use it to find the most used channel by state.

# %%
# %%sql
#
# SELECT state, channel, COUNT(*) AS count
# FROM calls
# GROUP BY state, channel ORDER BY count DESC;
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 204 rows affected.
# [('Texas               ', 'Call-Center         ', 1137),
#  ('California          ', 'Call-Center         ', 1092),
#  ('California          ', 'Chatbot             ', 962),
#  ('Florida             ', 'Call-Center         ', 923),
#  ('Texas               ', 'Chatbot             ', 899),
#  ('California          ', 'Email               ', 831),
#  ('Texas               ', 'Email               ', 805),
#  ('California          ', 'Web                 ', 746),
#  ('Texas               ', 'Web                 ', 731),
#  ('Florida             ', 'Chatbot             ', 694),
#  ('Florida             ', 'Email               ', 639),
#  ('New York            ', 'Call-Center         ', 580),
#  ('Florida             ', 'Web                 ', 578),
#  ('New York            ', 'Chatbot             ', 463),
#  ('New York            ', 'Email               ', 411),
#  ('Virginia            ', 'Call-Center         ', 384),
#  ('District of Columbia', 'Call-Center         ', 375),
#  ('Ohio                ', 'Call-Center         ', 372),
#  ('New York            ', 'Web                 ', 332),
#  ('Pennsylvania        ', 'Call-Center         ', 328),
#  ('Georgia             ', 'Call-Center         ', 304),
#  ('Ohio                ', 'Chatbot             ', 301),
#  ('Illinois            ', 'Call-Center         ', 295),
#  ('District of Columbia', 'Chatbot             ', 293),
#  ('Virginia            ', 'Email               ', 273),
#  ('Virginia            ', 'Chatbot             ', 272),
#  ('Colorado            ', 'Call-Center         ', 266),
#  ('Arizona             ', 'Call-Center         ', 265),
#  ('Ohio                ', 'Email               ', 259),
#  ('Pennsylvania        ', 'Chatbot             ', 256),
#  ('District of Columbia', 'Email               ', 252),
#  ('North Carolina      ', 'Call-Center         ', 252),
#  ('Indiana             ', 'Call-Center         ', 245),
#  ('Georgia             ', 'Chatbot             ', 241),
#  ('Virginia            ', 'Web                 ', 235),
#  ('Pennsylvania        ', 'Email               ', 232),
#  ('Ohio                ', 'Web                 ', 228),
#  ('Alabama             ', 'Call-Center         ', 224),
#  ('Minnesota           ', 'Call-Center         ', 222),
#  ('Missouri            ', 'Call-Center         ', 221),
#  ('Tennessee           ', 'Call-Center         ', 215),
#  ('Louisiana           ', 'Call-Center         ', 212),
#  ('Washington          ', 'Call-Center         ', 212),
#  ('Georgia             ', 'Email               ', 209),
#  ('Pennsylvania        ', 'Web                 ', 201),
#  ('Illinois            ', 'Email               ', 197),
#  ('District of Columbia', 'Web                 ', 190),
#  ('Illinois            ', 'Chatbot             ', 189),
#  ('Indiana             ', 'Chatbot             ', 187),
#  ('Alabama             ', 'Chatbot             ', 186),
#  ('North Carolina      ', 'Chatbot             ', 183),
#  ('Minnesota           ', 'Chatbot             ', 180),
#  ('Michigan            ', 'Call-Center         ', 180),
#  ('Colorado            ', 'Chatbot             ', 180),
#  ('Alabama             ', 'Email               ', 176),
#  ('Louisiana           ', 'Chatbot             ', 175),
#  ('North Carolina      ', 'Email               ', 173),
#  ('Washington          ', 'Chatbot             ', 173),
#  ('Oklahoma            ', 'Call-Center         ', 173),
#  ('Minnesota           ', 'Email               ', 172),
#  ('Georgia             ', 'Web                 ', 172),
#  ('Indiana             ', 'Email               ', 168),
#  ('Michigan            ', 'Chatbot             ', 168),
#  ('Illinois            ', 'Web                 ', 167),
#  ('Arizona             ', 'Email               ', 163),
#  ('Kansas              ', 'Call-Center         ', 162),
#  ('Tennessee           ', 'Chatbot             ', 162),
#  ('Arizona             ', 'Web                 ', 158),
#  ('Missouri            ', 'Email               ', 157),
#  ('Washington          ', 'Email               ', 157),
#  ('North Carolina      ', 'Web                 ', 157),
#  ('Missouri            ', 'Chatbot             ', 157),
#  ('Michigan            ', 'Email               ', 155),
#  ('Massachusetts       ', 'Call-Center         ', 155),
#  ('Alabama             ', 'Web                 ', 152),
#  ('Connecticut         ', 'Call-Center         ', 151),
#  ('Arizona             ', 'Chatbot             ', 151),
#  ('Colorado            ', 'Email               ', 149),
#  ('Tennessee           ', 'Email               ', 149),
#  ('Missouri            ', 'Web                 ', 147),
#  ('Colorado            ', 'Web                 ', 147),
#  ('Nevada              ', 'Call-Center         ', 142),
#  ('Massachusetts       ', 'Chatbot             ', 139),
#  ('Minnesota           ', 'Web                 ', 138),
#  ('Tennessee           ', 'Web                 ', 138),
#  ('Oklahoma            ', 'Chatbot             ', 138),
#  ('Indiana             ', 'Web                 ', 136),
#  ('Kentucky            ', 'Call-Center         ', 134),
#  ('Maryland            ', 'Call-Center         ', 126),
#  ('Louisiana           ', 'Web                 ', 126),
#  ('Oklahoma            ', 'Email               ', 122),
#  ('Washington          ', 'Web                 ', 121),
#  ('Nevada              ', 'Chatbot             ', 115),
#  ('Louisiana           ', 'Email               ', 114),
#  ('Iowa                ', 'Call-Center         ', 112),
#  ('Maryland            ', 'Email               ', 110),
#  ('Wisconsin           ', 'Call-Center         ', 109),
#  ('Michigan            ', 'Web                 ', 109),
#  ('New Jersey          ', 'Call-Center         ', 109),
#  ('Kansas              ', 'Email               ', 108),
#  ('Nevada              ', 'Email               ', 107),
#  ('Oklahoma            ', 'Web                 ', 105),
#  ('Utah                ', 'Call-Center         ', 104),
#  ('Connecticut         ', 'Chatbot             ', 101),
#  ('Kansas              ', 'Chatbot             ', 100),
#  ('Massachusetts       ', 'Email               ', 100),
#  ('Maryland            ', 'Chatbot             ', 99),
#  ('Massachusetts       ', 'Web                 ', 99),
#  ('West Virginia       ', 'Call-Center         ', 98),
#  ('Kentucky            ', 'Chatbot             ', 98),
#  ('Kansas              ', 'Web                 ', 97),
#  ('Kentucky            ', 'Email               ', 96),
#  ('South Carolina      ', 'Call-Center         ', 95),
#  ('Nevada              ', 'Web                 ', 95),
#  ('Iowa                ', 'Chatbot             ', 91),
#  ('Wisconsin           ', 'Chatbot             ', 88),
#  ('South Carolina      ', 'Email               ', 83),
#  ('Kentucky            ', 'Web                 ', 83),
#  ('Iowa                ', 'Web                 ', 82),
#  ('Iowa                ', 'Email               ', 81),
#  ('Nebraska            ', 'Call-Center         ', 80),
#  ('Connecticut         ', 'Web                 ', 80),
#  ('Maryland            ', 'Web                 ', 80),
#  ('West Virginia       ', 'Chatbot             ', 79),
#  ('Oregon              ', 'Call-Center         ', 77),
#  ('Wisconsin           ', 'Email               ', 77),
#  ('Mississippi         ', 'Call-Center         ', 76),
#  ('Connecticut         ', 'Email               ', 76),
#  ('Oregon              ', 'Chatbot             ', 74),
#  ('New Jersey          ', 'Chatbot             ', 73),
#  ('New Jersey          ', 'Email               ', 73),
#  ('Utah                ', 'Chatbot             ', 73),
#  ('South Carolina      ', 'Chatbot             ', 72),
#  ('Wisconsin           ', 'Web                 ', 68),
#  ('West Virginia       ', 'Email               ', 68),
#  ('South Carolina      ', 'Web                 ', 65),
#  ('Oregon              ', 'Web                 ', 64),
#  ('Utah                ', 'Email               ', 63),
#  ('Idaho               ', 'Call-Center         ', 63),
#  ('New Jersey          ', 'Web                 ', 62),
#  ('Nebraska            ', 'Chatbot             ', 59),
#  ('New Mexico          ', 'Call-Center         ', 59),
#  ('Utah                ', 'Web                 ', 58),
#  ('Arkansas            ', 'Email               ', 58),
#  ('Arkansas            ', 'Call-Center         ', 57),
#  ('Nebraska            ', 'Email               ', 57),
#  ('New Mexico          ', 'Chatbot             ', 56),
#  ('West Virginia       ', 'Web                 ', 56),
#  ('Arkansas            ', 'Chatbot             ', 54),
#  ('New Mexico          ', 'Email               ', 50),
#  ('Hawaii              ', 'Call-Center         ', 49),
#  ('New Mexico          ', 'Web                 ', 47),
#  ('Nebraska            ', 'Web                 ', 47),
#  ('Oregon              ', 'Email               ', 46),
#  ('Hawaii              ', 'Chatbot             ', 45),
#  ('Delaware            ', 'Call-Center         ', 43),
#  ('Idaho               ', 'Web                 ', 43),
#  ('Alaska              ', 'Call-Center         ', 41),
#  ('Alaska              ', 'Email               ', 40),
#  ('Idaho               ', 'Email               ', 40),
#  ('Mississippi         ', 'Chatbot             ', 38),
#  ('Arkansas            ', 'Web                 ', 35),
#  ('Alaska              ', 'Chatbot             ', 34),
#  ('Mississippi         ', 'Web                 ', 32),
#  ('Mississippi         ', 'Email               ', 32),
#  ('Alaska              ', 'Web                 ', 31),
#  ('Delaware            ', 'Email               ', 30),
#  ('South Dakota        ', 'Call-Center         ', 30),
#  ('Delaware            ', 'Chatbot             ', 29),
#  ('Hawaii              ', 'Web                 ', 29),
#  ('Idaho               ', 'Chatbot             ', 28),
#  ('South Dakota        ', 'Chatbot             ', 28),
#  ('Hawaii              ', 'Email               ', 26),
#  ('Delaware            ', 'Web                 ', 26),
#  ('Montana             ', 'Call-Center         ', 26),
#  ('Montana             ', 'Email               ', 23),
#  ('Montana             ', 'Web                 ', 23),
#  ('Montana             ', 'Chatbot             ', 22),
#  ('North Dakota        ', 'Call-Center         ', 22),
#  ('North Dakota        ', 'Web                 ', 20),
#  ('South Dakota        ', 'Web                 ', 19),
#  ('North Dakota        ', 'Chatbot             ', 18),
#  ('New Hampshire       ', 'Chatbot             ', 17),
#  ('North Dakota        ', 'Email               ', 16),
#  ('South Dakota        ', 'Email               ', 16),
#  ('Rhode Island        ', 'Call-Center         ', 12),
#  ('New Hampshire       ', 'Call-Center         ', 12),
#  ('New Hampshire       ', 'Web                 ', 11),
#  ('New Hampshire       ', 'Email               ', 11),
#  ('Rhode Island        ', 'Chatbot             ', 10),
#  ('Rhode Island        ', 'Email               ', 10),
#  ('Wyoming             ', 'Call-Center         ', 7),
#  ('Maine               ', 'Call-Center         ', 7),
#  ('Maine               ', 'Email               ', 5),
#  ('Vermont             ', 'Email               ', 4),
#  ('Vermont             ', 'Call-Center         ', 4),
#  ('Vermont             ', 'Web                 ', 4),
#  ('Maine               ', 'Chatbot             ', 3),
#  ('Rhode Island        ', 'Web                 ', 3),
#  ('Vermont             ', 'Chatbot             ', 2),
#  ('Wyoming             ', 'Web                 ', 2),
#  ('Maine               ', 'Web                 ', 1),
#  ('Wyoming             ', 'Email               ', 1),
#  ('Wyoming             ', 'Chatbot             ', 1)]

# %% [markdown]
# It looks like that call center channel is the most used channel. And the state that use it the most is in Texas with 1.137 total calls.

# %% [markdown]
# ### 9. What is the most sentiment?

# %% [markdown]
# Let's see the total sentiment given by the customer based on the sentiment

# %%
# %%sql
#
# SELECT sentiment, COUNT(*),
# ROUND(COUNT(*) * 100.0/ (SELECT COUNT(*) FROM calls) ,2) AS percentage
# FROM calls GROUP BY sentiment ORDER BY sentiment ASC;
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 5 rows affected.
# [('Negative            ', 11063, Decimal('33.58')),
#  ('Neutral             ', 8754, Decimal('26.57')),
#  ('Positive            ', 3928, Decimal('11.92')),
#  ('Very Negative       ', 6026, Decimal('18.29')),
#  ('Very Positive       ', 3170, Decimal('9.62'))]

# %% [markdown]
# According to the result we get that Negative Sentiment is the sentiment that has been given the most by customers. The Negative sentiment has 11.063 total or 33.58%. Whereas Very Positive is the least sentiment with 3.170 total or 9.62%.

# %% [markdown]
# ### 10. Who has given the 'Very Positive' and 'Positive' sentiments?

# %% [markdown]
# After got the sentiments total, let's find out the customer name that gives 'Very Positive' and 'Positive'  sentiment.

# %%
# %%sql
#
# SELECT customer_name, sentiment
# FROM calls
# WHERE sentiment = 'Very Positive' OR sentiment = 'Positive'
# GROUP BY sentiment, customer_name ORDER BY sentiment;
# Out:
#  * postgresql://postgres:***@localhost/Project1
# 7098 rows affected.
# [('Aarika Partleton                                  ', 'Positive            '),
#  ('Aaron Skains                                      ', 'Positive            '),
#  ('Abbey Elvish                                      ', 'Positive            '),
#  ('Abbi Martineau                                    ', 'Positive            '),
#  ('Abbie Duhig                                       ', 'Positive            '),
#  ('Abbott Shorton                                    ', 'Positive            '),
#  ('Abdul Mulhall                                     ', 'Positive            '),
#  ('Abel Douris                                       ', 'Positive            '),
#  ('Abelard Formilli                                  ', 'Positive            '),
#  ('Abeu Anwyl                                        ', 'Positive            '),
#  ('Abeu Gallety                                      ', 'Positive            '),
#  ('Abey Alyokhin                                     ', 'Positive            '),
#  ('Abie Lambert                                      ', 'Positive            '),
#  ('Abigael Vassman                                   ', 'Positive            '),
#  ('Abrahan Sansum                                    ', 'Positive            '),
#  ('Abran Jachimak                                    ', 'Positive            '),
#  ('Ada Gowling                                       ', 'Positive            '),
#  ('Ada Porkiss                                       ', 'Positive            '),
#  ('Adam Weightman                                    ', 'Positive            '),
#  ('Adamo Cadogan                                     ', 'Positive            '),
#  ('Adamo Cases                                       ', 'Positive            '),
#  ('Adams Lardge                                      ', 'Positive            '),
#  ('Adan Gajewski                                     ', 'Positive            '),
#  ('Addia Cornell                                     ', 'Positive            '),
#  ('Addie Springham                                   ', 'Positive            '),
#  ('Adelaida Grenshields                              ', 'Positive            '),
#  ('Adele Christou                                    ', 'Positive            '),
#  ('Adelheid Wharmby                                  ', 'Positive            '),
#  ('Adella Sicha                                      ', 'Positive            '),
#  ('Adelle Nower                                      ', 'Positive            '),
#  ('Adelle Todarello                                  ', 'Positive            '),
#  ('Adiana McGuckin                                   ', 'Positive            '),
#  ('Adolpho Jaulme                                    ', 'Positive            '),
#  ('Adolphus Harbottle                                ', 'Positive            '),
#  ('Adora Botterman                                   ', 'Positive            '),
#  ('Adora Easterbrook                                 ', 'Positive            '),
#  ('Adorne Bricksey                                   ', 'Positive            '),
#  ('Adria De Bruijn                                   ', 'Positive            '),
#  ('Adria Rennison                                    ', 'Positive            '),
#  ('Adriana Crehan                                    ', 'Positive            '),
#  ('Adrianna Fishpoole                                ', 'Positive            '),
#  ('Adrianne Wrangle                                  ', 'Positive            '),
#  ('Aeriela Slym                                      ', 'Positive            '),
#  ('Aeriell Perutto                                   ', 'Positive            '),
#  ('Agatha Kenington                                  ', 'Positive            '),
#  ('Agatha Moorcraft                                  ', 'Positive            '),
#  ('Aggie Cliss                                       ', 'Positive            '),
#  ('Aggie Pawfoot                                     ', 'Positive            '),
#  ('Agnes Watmough                                    ', 'Positive            '),
#  ('Agnese Chalk                                      ', 'Positive            '),
#  ('Agnese Petrolli                                   ', 'Positive            '),
#  ('Agnesse Message                                   ', 'Positive            '),
#  ('Agretha Gregori                                   ', 'Positive            '),
#  ('Agretha Upsale                                    ', 'Positive            '),
#  ('Aguie Brideoke                                    ', 'Positive            '),
#  ('Aharon Kairns                                     ', 'Positive            '),
#  ('Aida McKea                                        ', 'Positive            '),
#  ('Aila Bengochea                                    ', 'Positive            '),
#  ('Aila Petheridge                                   ', 'Positive            '),
#  ('Aile Brampton                                     ', 'Positive            '),
#  ('Ailee Bruneau                                     ', 'Positive            '),
#  ('Ailene Paddy                                      ', 'Positive            '),
#  ('Ailis Mutton                                      ', 'Positive            '),
#  ('Ailyn Ellar                                       ', 'Positive            '),
#  ('Aimee McNamee                                     ', 'Positive            '),
#  ('Aimil Carlucci                                    ', 'Positive            '),
#  ('Ainsley Whitfield                                 ', 'Positive            '),
#  ('Akim Gildersleaves                                ', 'Positive            '),
#  ('Aksel Rignoldes                                   ', 'Positive            '),
#  ('Alaine Fockes                                     ', 'Positive            '),
#  ('Alan Itshak                                       ', 'Positive            '),
#  ('Alana Dudden                                      ', 'Positive            '),
#  ('Aland Berrisford                                  ', 'Positive            '),
#  ('Alanna Burrells                                   ', 'Positive            '),
#  ('Alard Kunes                                       ', 'Positive            '),
#  ('Alasdair McInnes                                  ', 'Positive            '),
#  ('Alasdair Wapples                                  ', 'Positive            '),
#  ('Alasteir Gasker                                   ', 'Positive            '),
#  ('Alayne Tuther                                     ', 'Positive            '),
#  ('Alberik Bertomier                                 ', 'Positive            '),
#  ('Alberta Wescott                                   ', 'Positive            '),
#  ('Albrecht Matzkaitis                               ', 'Positive            '),
#  ('Aldis Mc Carroll                                  ', 'Positive            '),
#  ('Aldo Artrick                                      ', 'Positive            '),
#  ('Aldous Nevett                                     ', 'Positive            '),
#  ('Aldous Truluck                                    ', 'Positive            '),
#  ('Aldridge Godbehere                                ', 'Positive            '),
#  ('Aldwin Slessar                                    ', 'Positive            '),
#  ('Alecia Keedy                                      ', 'Positive            '),
#  ('Aleda Capeling                                    ', 'Positive            '),
#  ('Aleda Gunther                                     ', 'Positive            '),
#  ('Aleen Duce                                        ', 'Positive            '),
#  ('Alejandrina Caffrey                               ', 'Positive            '),
#  ('Alejandro Bercher                                 ', 'Positive            '),
#  ('Alexandra Harriot                                 ', 'Positive            '),
#  ('Alexandrina Werner                                ', 'Positive            '),
#  ('Alexei Svanini                                    ', 'Positive            '),
#  ('Alexi Soares                                      ', 'Positive            '),
#  ('Alexina Molder                                    ', 'Positive            '),
#  ('Alexis Tonnesen                                   ', 'Positive            '),
#  ('Alfie Ladlow                                      ', 'Positive            '),
#  ('Alfons Rehorek                                    ', 'Positive            '),
#  ('Alfonso Ardling                                   ', 'Positive            '),
#  ('Alfy Crowter                                      ', 'Positive            '),
#  ('Alfy Sansbury                                     ', 'Positive            '),
#  ('Alia Humbatch                                     ', 'Positive            '),
#  ('Alica Linklater                                   ', 'Positive            '),
#  ('Alicea Paulot                                     ', 'Positive            '),
#  ('Alicia Azemar                                     ', 'Positive            '),
#  ('Alick McKerron                                    ', 'Positive            '),
#  ('Alick Tofano                                      ', 'Positive            '),
#  ('Alikee Aubery                                     ', 'Positive            '),
#  ('Aline Chadd                                       ', 'Positive            '),
#  ('Alis Firmager                                     ', 'Positive            '),
#  ('Alisander Alsford                                 ', 'Positive            '),
#  ('Alisander Blaszczak                               ', 'Positive            '),
#  ('Alison Balsellie                                  ', 'Positive            '),
#  ('Alister Blenkin                                   ', 'Positive            '),
#  ('Alisun Sturmey                                    ', 'Positive            '),
#  ('Alix Woolham                                      ', 'Positive            '),
#  ('Aliza Gritten                                     ', 'Positive            '),
#  ('Aliza Mickan                                      ', 'Positive            '),
#  ('Alleen Buttery                                    ', 'Positive            '),
#  ('Alley Beeching                                    ', 'Positive            '),
#  ('Alleyn Blofield                                   ', 'Positive            '),
#  ('Allie Braitling                                   ', 'Positive            '),
#  ('Allie Gemelli                                     ', 'Positive            '),
#  ('Allie Turrill                                     ', 'Positive            '),
#  ('Allissa Beauvais                                  ', 'Positive            '),
#  ('Allister Giacobelli                               ', 'Positive            '),
#  ('Allyn Ewers                                       ', 'Positive            '),
#  ('Allyn Shoreson                                    ', 'Positive            '),
#  ('Almeria Turfin                                    ', 'Positive            '),
#  ('Almeria Wood                                      ', 'Positive            '),
#  ('Almira Friday                                     ', 'Positive            '),
#  ('Almire Flood                                      ', 'Positive            '),
#  ('Almire Harse                                      ', 'Positive            '),
#  ('Aloise Paladini                                   ', 'Positive            '),
#  ('Aloisia Zecchii                                   ', 'Positive            '),
#  ('Aloysia Gilardone                                 ', 'Positive            '),
#  ('Alphonse Bowton                                   ', 'Positive            '),
#  ('Alphonso Raynham                                  ', 'Positive            '),
#  ('Alric Banbridge                                   ', 'Positive            '),
#  ('Alric Handford                                    ', 'Positive            '),
#  ('Aluino Izhak                                      ', 'Positive            '),
#  ('Alva Sapsford                                     ', 'Positive            '),
#  ('Alvera Elger                                      ', 'Positive            '),
#  ('Alvera Juanes                                     ', 'Positive            '),
#  ('Alvina Harwick                                    ', 'Positive            '),
#  ('Alvira Philippsohn                                ', 'Positive            '),
#  ('Alvira Phillips                                   ', 'Positive            '),
#  ('Alvy Kubas                                        ', 'Positive            '),
#  ('Alvy Mozzetti                                     ', 'Positive            '),
#  ('Alvy Schimaschke                                  ', 'Positive            '),
#  ('Alyce MacCallam                                   ', 'Positive            '),
#  ('Alyda Thorndycraft                                ', 'Positive            '),
#  ('Alysa Oulet                                       ', 'Positive            '),
#  ('Alyse Graeber                                     ', 'Positive            '),
#  ('Alyse Wilsey                                      ', 'Positive            '),
#  ('Amabel Repp                                       ', 'Positive            '),
#  ('Amalea Darley                                     ', 'Positive            '),
#  ('Amalee Lemmon                                     ', 'Positive            '),
#  ('Amalee Radbond                                    ', 'Positive            '),
#  ('Amaleta Curman                                    ', 'Positive            '),
#  ('Amaleta Widmore                                   ', 'Positive            '),
#  ('Amalia Conroy                                     ', 'Positive            '),
#  ('Amalie Ingle                                      ', 'Positive            '),
#  ('Amandi Edmonds                                    ', 'Positive            '),
#  ('Amandie Sommerton                                 ', 'Positive            '),
#  ('Amandy Battman                                    ', 'Positive            '),
#  ('Amandy Coleiro                                    ', 'Positive            '),
#  ('Amargo Eplate                                     ', 'Positive            '),
#  ('Amberly Klich                                     ', 'Positive            '),
#  ('Amberly Marioneau                                 ', 'Positive            '),
#  ('Ambrose Avarne                                    ', 'Positive            '),
#  ('Ame Syversen                                      ', 'Positive            '),
#  ('Amelie McCurt                                     ', 'Positive            '),
#  ('Amelina Mannooch                                  ', 'Positive            '),
#  ('Amerigo Misken                                    ', 'Positive            '),
#  ('Ami Culshew                                       ', 'Positive            '),
#  ('Amie Jobin                                        ', 'Positive            '),
#  ('Amii Tommeo                                       ', 'Positive            '),
#  ('Amory Fowden                                      ', 'Positive            '),
#  ('Amy Kubista                                       ', 'Positive            '),
#  ('Amye Dunstall                                     ', 'Positive            '),
#  ('Anabel Vivers                                     ', 'Positive            '),
#  ('Analiese Searle                                   ', 'Positive            '),
#  ('Analise Bulfield                                  ', 'Positive            '),
#  ('Anastassia Kitteman                               ', 'Positive            '),
#  ('Anastassia Mertin                                 ', 'Positive            '),
#  ('Anatola Bedwell                                   ', 'Positive            '),
#  ('Andeee Reynoollds                                 ', 'Positive            '),
#  ('Andi Chicco                                       ', 'Positive            '),
#  ('Andi Dallander                                    ', 'Positive            '),
#  ('Andonis Marien                                    ', 'Positive            '),
#  ('Andras Farny                                      ', 'Positive            '),
#  ('Andras Phillpot                                   ', 'Positive            '),
#  ('Andrea McKelvey                                   ', 'Positive            '),
#  ('Andrea Tooby                                      ', 'Positive            '),
#  ('Andreana Cayet                                    ', 'Positive            '),
#  ('Andreana Collough                                 ', 'Positive            '),
#  ('Andrej Sulter                                     ', 'Positive            '),
#  ('Andrej Tsar                                       ', 'Positive            '),
#  ('Andres Joules                                     ', 'Positive            '),
#  ('Andres Wycherley                                  ', 'Positive            '),
#  ('Andris Lerwell                                    ', 'Positive            '),
#  ('Andris Pugsley                                    ', 'Positive            '),
#  ('Andy Matchell                                     ', 'Positive            '),
#  ('Anet Donne                                        ', 'Positive            '),
#  ('Ange Deschlein                                    ', 'Positive            '),
#  ('Ange Ithell                                       ', 'Positive            '),
#  ('Ange Macquire                                     ', 'Positive            '),
#  ('Angel Rowlings                                    ', 'Positive            '),
#  ('Angela Wheldon                                    ', 'Positive            '),
#  ('Angeli Titt                                       ', 'Positive            '),
#  ('Angeline Shay                                     ', 'Positive            '),
#  ('Angelita Turrell                                  ', 'Positive            '),
#  ('Angie Craw                                        ', 'Positive            '),
#  ('Angie Ferreli                                     ', 'Positive            '),
#  ("Angus O' Cloney                                   ", 'Positive            '),
#  ('Angy Barck                                        ', 'Positive            '),
#  ('Anica Roffey                                      ', 'Positive            '),
#  ('Anissa Goodale                                    ', 'Positive            '),
#  ('Anita Jandl                                       ', 'Positive            '),
#  ('Anita Larive                                      ', 'Positive            '),
#  ('Anjela Beeton                                     ', 'Positive            '),
#  ('Ann Noseworthy                                    ', 'Positive            '),
#  ('Anna-diana Weerdenburg                            ', 'Positive            '),
#  ('Anna-diane Fashion                                ', 'Positive            '),
#  ('Anna-diane Woodgate                               ', 'Positive            '),
#  ('Anna-maria Collingworth                           ', 'Positive            '),
#  ('Annabell Dowber                                   ', 'Positive            '),
#  ('Annabelle Jiggen                                  ', 'Positive            '),
#  ('Annadiana Dewes                                   ', 'Positive            '),
#  ('Annalee Heyworth                                  ', 'Positive            '),
#  ('Anne-marie Clooney                                ', 'Positive            '),
#  ('Annecorinne Barbier                               ', 'Positive            '),
#  ('Annelise Aleksandrikin                            ', 'Positive            '),
#  ('Annemarie McConnachie                             ', 'Positive            '),
#  ('Annetta Chillingworth                             ', 'Positive            '),
#  ('Annette Phillis                                   ', 'Positive            '),
#  ('Annie Marden                                      ', 'Positive            '),
#  ('Annie Oxbe                                        ', 'Positive            '),
#  ('Annis Daye                                        ', 'Positive            '),
#  ('Annissa Lempenny                                  ', 'Positive            '),
#  ('Annmaria Evenett                                  ', 'Positive            '),
#  ('Annmaria Mosedale                                 ', 'Positive            '),
#  ('Annnora Geraldo                                   ', 'Positive            '),
#  ('Annora Cescotti                                   ', 'Positive            '),
#  ('Annora McLennan                                   ', 'Positive            '),
#  ('Anselm Eakeley                                    ', 'Positive            '),
#  ('Ansley Devonside                                  ', 'Positive            '),
#  ('Antoinette Jailler                                ', 'Positive            '),
#  ('Antonella Grasser                                 ', 'Positive            '),
#  ('Antonetta Tapton                                  ', 'Positive            '),
#  ('Antoni Charlet                                    ', 'Positive            '),
#  ('Antoni Spottswood                                 ', 'Positive            '),
#  ('Antonius Bows                                     ', 'Positive            '),
#  ('April Barber                                      ', 'Positive            '),
#  ('April Kneale                                      ', 'Positive            '),
#  ('Arabele Widmore                                   ', 'Positive            '),
#  ('Arabella Ingle                                    ', 'Positive            '),
#  ('Arch Ebbutt                                       ', 'Positive            '),
#  ('Archaimbaud Slaney                                ', 'Positive            '),
#  ('Archibald Ughetti                                 ', 'Positive            '),
#  ('Archibaldo Richardes                              ', 'Positive            '),
#  ('Archie Paine                                      ', 'Positive            '),
#  ('Arda Grindley                                     ', 'Positive            '),
#  ('Ardeen Shyres                                     ', 'Positive            '),
#  ('Ardelis Stammler                                  ', 'Positive            '),
#  ('Ardella Astman                                    ', 'Positive            '),
#  ('Ardella Wadham                                    ', 'Positive            '),
#  ('Arden Reihm                                       ', 'Positive            '),
#  ('Ardenia Nasey                                     ', 'Positive            '),
#  ('Ardisj Bagnall                                    ', 'Positive            '),
#  ('Ardith Josselson                                  ', 'Positive            '),
#  ('Ardith Renne                                      ', 'Positive            '),
#  ('Ardyce Mowsdell                                   ', 'Positive            '),
#  ('Ardys Romagnosi                                   ', 'Positive            '),
#  ('Arel Deniset                                      ', 'Positive            '),
#  ('Ari Cush                                          ', 'Positive            '),
#  ('Ariana McVitty                                    ', 'Positive            '),
#  ('Ariana Melly                                      ', 'Positive            '),
#  ('Ario Spurdens                                     ', 'Positive            '),
#  ('Arlan Rosenwald                                   ', 'Positive            '),
#  ('Arlee Linham                                      ', 'Positive            '),
#  ('Arleta Coaten                                     ', 'Positive            '),
#  ('Arleta Staniland                                  ', 'Positive            '),
#  ('Arlinda Castagnet                                 ', 'Positive            '),
#  ('Arluene Geal                                      ', 'Positive            '),
#  ('Arluene Kinnoch                                   ', 'Positive            '),
#  ('Arluene Strotton                                  ', 'Positive            '),
#  ('Arly Saxon                                        ', 'Positive            '),
#  ('Arnuad Puckey                                     ', 'Positive            '),
#  ('Arny Brecken                                      ', 'Positive            '),
#  ('Arny Gaskoin                                      ', 'Positive            '),
#  ('Aron Tilling                                      ', 'Positive            '),
#  ('Artemas Paprotny                                  ', 'Positive            '),
#  ('Arthur Norssister                                 ', 'Positive            '),
#  ('Arv Revie                                         ', 'Positive            '),
#  ('Aryn Woolner                                      ', 'Positive            '),
#  ('Ashbey Berends                                    ', 'Positive            '),
#  ('Ashely Marrett                                    ', 'Positive            '),
#  ('Asher Reaper                                      ', 'Positive            '),
#  ('Ashien Bulward                                    ', 'Positive            '),
#  ('Ashley Bourgeois                                  ', 'Positive            '),
#  ('Ashli Breadon                                     ', 'Positive            '),
#  ('Ashly Franzolini                                  ', 'Positive            '),
#  ('Astra McGregor                                    ', 'Positive            '),
#  ('Atalanta Banane                                   ', 'Positive            '),
#  ('Atalanta Berre                                    ', 'Positive            '),
#  ('Athena Ledwich                                    ', 'Positive            '),
#  ('Atlante Collopy                                   ', 'Positive            '),
#  ('Aube Jaan                                         ', 'Positive            '),
#  ('Auberon Laurenzi                                  ', 'Positive            '),
#  ('Aubine MacBrearty                                 ', 'Positive            '),
#  ('Aubree Mergue                                     ', 'Positive            '),
#  ('Aubrette Dunleavy                                 ', 'Positive            '),
#  ('Aubrey McGrowther                                 ', 'Positive            '),
#  ('Aubrie Goldstein                                  ', 'Positive            '),
#  ('Augie Jacquemot                                   ', 'Positive            '),
#  ('Augusta Renowden                                  ', 'Positive            '),
#  ('Augy Gwyllt                                       ', 'Positive            '),
#  ('Augy Philpotts                                    ', 'Positive            '),
#  ('Aundrea Rearden                                   ', 'Positive            '),
#  ('Aura Exer                                         ', 'Positive            '),
#  ('Aurelea Flockhart                                 ', 'Positive            '),
#  ('Aurelie Gundry                                    ', 'Positive            '),
#  ('Aurilia Proctor                                   ', 'Positive            '),
#  ('Austen Hirjak                                     ', 'Positive            '),
#  ('Austen Melliard                                   ', 'Positive            '),
#  ('Austin Guynemer                                   ', 'Positive            '),
#  ('Austina Swynfen                                   ', 'Positive            '),
#  ('Austine Wellfare                                  ', 'Positive            '),
#  ('Aveline Desborough                                ', 'Positive            '),
#  ('Aveline Goodlife                                  ', 'Positive            '),
#  ('Averell Reddan                                    ', 'Positive            '),
#  ('Averil Hambric                                    ', 'Positive            '),
#  ('Averyl Joontjes                                   ', 'Positive            '),
#  ('Avigdor Rowly                                     ', 'Positive            '),
#  ('Avis Gatley                                       ', 'Positive            '),
#  ('Avis Gianasi                                      ', 'Positive            '),
#  ('Aviva Pattillo                                    ', 'Positive            '),
#  ('Avivah Le Franc                                   ', 'Positive            '),
#  ('Avrom Greystock                                   ', 'Positive            '),
#  ('Axe Peealess                                      ', 'Positive            '),
#  ('Axel Mabee                                        ', 'Positive            '),
#  ('Axel May                                          ', 'Positive            '),
#  ('Aylmar Bocke                                      ', 'Positive            '),
#  ('Babara Mushawe                                    ', 'Positive            '),
#  ('Babara Rabbage                                    ', 'Positive            '),
#  ('Babb Helleckas                                    ', 'Positive            '),
#  ('Babita Oddboy                                     ', 'Positive            '),
#  ('Baillie Duffil                                    ', 'Positive            '),
#  ('Bale Iron                                         ', 'Positive            '),
#  ('Bambie Folbige                                    ', 'Positive            '),
#  ('Barbabas Rider                                    ', 'Positive            '),
#  ('Barbara-anne Kits                                 ', 'Positive            '),
#  ('Barbe Flowers                                     ', 'Positive            '),
#  ('Barbee Blaase                                     ', 'Positive            '),
#  ('Barbee Wank                                       ', 'Positive            '),
#  ('Barbette Beggi                                    ', 'Positive            '),
#  ('Barbette Kesten                                   ', 'Positive            '),
#  ('Barbette Rosso                                    ', 'Positive            '),
#  ('Barbey Blunn                                      ', 'Positive            '),
#  ('Barbey Latter                                     ', 'Positive            '),
#  ('Barde Synke                                       ', 'Positive            '),
#  ('Barney Alven                                      ', 'Positive            '),
#  ("Barney O'Dempsey                                  ", 'Positive            '),
#  ('Barny Kneafsey                                    ', 'Positive            '),
#  ('Barri Fanstone                                    ', 'Positive            '),
#  ('Bartel McDuffie                                   ', 'Positive            '),
#  ('Bartie Aldous                                     ', 'Positive            '),
#  ('Bartie Coxen                                      ', 'Positive            '),
#  ('Bartolomeo Challicombe                            ', 'Positive            '),
#  ('Baryram Snell                                     ', 'Positive            '),
#  ('Basile Coraini                                    ', 'Positive            '),
#  ('Batholomew Auten                                  ', 'Positive            '),
#  ('Batsheva Anthonies                                ', 'Positive            '),
#  ('Baudoin Chattoe                                   ', 'Positive            '),
#  ('Baudoin Dowle                                     ', 'Positive            '),
#  ('Bax Clues                                         ', 'Positive            '),
#  ("Bax d'Arcy                                        ", 'Positive            '),
#  ('Bax Halloran                                      ', 'Positive            '),
#  ('Bax Littlejohns                                   ', 'Positive            '),
#  ('Baxie Gelderd                                     ', 'Positive            '),
#  ('Bay Whetland                                      ', 'Positive            '),
#  ('Bea Durak                                         ', 'Positive            '),
#  ('Bea Motto                                         ', 'Positive            '),
#  ('Bea Skeleton                                      ', 'Positive            '),
#  ('Beale Congreave                                   ', 'Positive            '),
#  ('Bear Gossage                                      ', 'Positive            '),
#  ('Bearnard Peron                                    ', 'Positive            '),
#  ('Beatrice Fochs                                    ', 'Positive            '),
#  ('Beatrice Hammonds                                 ', 'Positive            '),
#  ('Beatrice Puckrin                                  ', 'Positive            '),
#  ('Beatrisa Harnor                                   ', 'Positive            '),
#  ('Beatrisa Tomasini                                 ', 'Positive            '),
#  ('Beatrix Iorizzo                                   ', 'Positive            '),
#  ('Beau Gerber                                       ', 'Positive            '),
#  ('Beaufort Kedward                                  ', 'Positive            '),
#  ('Bebe McKissack                                    ', 'Positive            '),
#  ('Becca Drewery                                     ', 'Positive            '),
#  ('Becca Dunphy                                      ', 'Positive            '),
#  ('Becky Moreside                                    ', 'Positive            '),
#  ('Beitris Siggens                                   ', 'Positive            '),
#  ('Bel Shaw                                          ', 'Positive            '),
#  ('Bel Shieldon                                      ', 'Positive            '),
#  ('Belinda Duran                                     ', 'Positive            '),
#  ('Belinda Grishaev                                  ', 'Positive            '),
#  ('Bell Bannerman                                    ', 'Positive            '),
#  ('Bella Trengrouse                                  ', 'Positive            '),
#  ('Bellina Sommerfeld                                ', 'Positive            '),
#  ('Belvia Switzer                                    ', 'Positive            '),
#  ('Bendicty Suckling                                 ', 'Positive            '),
#  ('Bendix Shawe                                      ', 'Positive            '),
#  ('Benedetta Eglin                                   ', 'Positive            '),
#  ('Benedetto Gierck                                  ', 'Positive            '),
#  ('Benedick Giffen                                   ', 'Positive            '),
#  ('Beniamino Bale                                    ', 'Positive            '),
#  ('Benji Trappe                                      ', 'Positive            '),
#  ('Benjy Dows                                        ', 'Positive            '),
#  ('Bennie Esparza                                    ', 'Positive            '),
#  ('Bennie Hiddersley                                 ', 'Positive            '),
#  ('Bennie Molfino                                    ', 'Positive            '),
#  ('Benny Pellatt                                     ', 'Positive            '),
#  ('Benoit Sherrard                                   ', 'Positive            '),
#  ('Benson Whaymand                                   ', 'Positive            '),
#  ('Bentlee Halsworth                                 ', 'Positive            '),
#  ('Bentley Jirek                                     ', 'Positive            '),
#  ('Benyamin Jaukovic                                 ', 'Positive            '),
#  ('Ber Bachs                                         ', 'Positive            '),
#  ('Berenice Hildrew                                  ', 'Positive            '),
#  ('Beret Maltby                                      ', 'Positive            '),
#  ('Berk Catterson                                    ', 'Positive            '),
#  ('Berk Gherardesci                                  ', 'Positive            '),
#  ('Berkley Speirs                                    ', 'Positive            '),
#  ('Berkly Brailey                                    ', 'Positive            '),
#  ('Berkly Heinzel                                    ', 'Positive            '),
#  ('Berky Ettery                                      ', 'Positive            '),
#  ('Berky Triswell                                    ', 'Positive            '),
#  ('Bern Ravilus                                      ', 'Positive            '),
#  ('Bern Walcher                                      ', 'Positive            '),
#  ("Berna O' Gara                                     ", 'Positive            '),
#  ('Bernadette Burnard                                ', 'Positive            '),
#  ('Bernadette Westrey                                ', 'Positive            '),
#  ('Bernadina Kersaw                                  ', 'Positive            '),
#  ('Bernadina Middler                                 ', 'Positive            '),
#  ('Bernadina Sotheby                                 ', 'Positive            '),
#  ('Bernardina Antuoni                                ', 'Positive            '),
#  ('Bernardine Snazle                                 ', 'Positive            '),
#  ('Bernelle Benda                                    ', 'Positive            '),
#  ('Bernelle Olivella                                 ', 'Positive            '),
#  ('Bernette Maestro                                  ', 'Positive            '),
#  ('Berni Jochanany                                   ', 'Positive            '),
#  ('Bernie Drust                                      ', 'Positive            '),
#  ('Berrie Brookzie                                   ', 'Positive            '),
#  ('Berry Bednell                                     ', 'Positive            '),
#  ('Bert Banbury                                      ', 'Positive            '),
#  ('Bert Chandlar                                     ', 'Positive            '),
#  ('Bert Haliburton                                   ', 'Positive            '),
#  ('Berta Evill                                       ', 'Positive            '),
#  ('Bertha Windress                                   ', 'Positive            '),
#  ('Berthe Leary                                      ', 'Positive            '),
#  ('Bertine Fain                                      ', 'Positive            '),
#  ('Berton Dumsday                                    ', 'Positive            '),
#  ('Bertrand Bowller                                  ', 'Positive            '),
#  ('Berty Flasby                                      ', 'Positive            '),
#  ('Beryl Collop                                      ', 'Positive            '),
#  ('Beryl Lovitt                                      ', 'Positive            '),
#  ('Bessie Burdytt                                    ', 'Positive            '),
#  ('Bethina Casillas                                  ', 'Positive            '),
#  ('Bethina Fazzioli                                  ', 'Positive            '),
#  ('Betsey Yu                                         ', 'Positive            '),
#  ('Bette-ann Plume                                   ', 'Positive            '),
#  ('Betteann Billingham                               ', 'Positive            '),
#  ('Betteann Geer                                     ', 'Positive            '),
#  ('Betteanne Ceccoli                                 ', 'Positive            '),
#  ('Betty Wrist                                       ', 'Positive            '),
#  ('Beulah Tasseler                                   ', 'Positive            '),
#  ('Bev Heimes                                        ', 'Positive            '),
#  ('Bevan Sterley                                     ', 'Positive            '),
#  ('Beverie Jandak                                    ', 'Positive            '),
#  ('Beverie Wilne                                     ', 'Positive            '),
#  ('Bianka Boutton                                    ', 'Positive            '),
#  ("Bibbye O' Hern                                    ", 'Positive            '),
#  ('Biddie Champagne                                  ', 'Positive            '),
#  ('Biddie Gillow                                     ', 'Positive            '),
#  ('Bidget Newns                                      ', 'Positive            '),
#  ('Bill Bayns                                        ', 'Positive            '),
#  ('Billi Creebo                                      ', 'Positive            '),
#  ('Bing Olphert                                      ', 'Positive            '),
#  ('Bink Woolway                                      ', 'Positive            '),
#  ('Binky Hartman                                     ', 'Positive            '),
#  ('Binnie Glazyer                                    ', 'Positive            '),
#  ('Birdie Harrad                                     ', 'Positive            '),
#  ('Birdie Manterfield                                ', 'Positive            '),
#  ('Birdie Trayling                                   ', 'Positive            '),
#  ('Birgitta Dallosso                                 ', 'Positive            '),
#  ('Birgitta Klawi                                    ', 'Positive            '),
#  ('Birgitta Stille                                   ', 'Positive            '),
#  ('Birk Crisell                                      ', 'Positive            '),
#  ('Bjorn Aiskrigg                                    ', 'Positive            '),
#  ('Bjorn Mosdall                                     ', 'Positive            '),
#  ('Blair Ivashchenko                                 ', 'Positive            '),
#  ('Blair Phinnessy                                   ', 'Positive            '),
#  ('Blake Gildersleeve                                ', 'Positive            '),
#  ('Blake Mulles                                      ', 'Positive            '),
#  ('Blakelee Leachman                                 ', 'Positive            '),
#  ('Blancha Vasichev                                  ', 'Positive            '),
#  ('Blayne Cestard                                    ', 'Positive            '),
#  ('Blinnie Pitherick                                 ', 'Positive            '),
#  ('Blinny Collyer                                    ', 'Positive            '),
#  ('Blinny Crickett                                   ', 'Positive            '),
#  ('Blinny Shilladay                                  ', 'Positive            '),
#  ('Bliss Boays                                       ', 'Positive            '),
#  ('Blondy Quene                                      ', 'Positive            '),
#  ('Bob Grieveson                                     ', 'Positive            '),
#  ('Bob Petz                                          ', 'Positive            '),
#  ('Bobbee Bridge                                     ', 'Positive            '),
#  ('Bobbette Du Pre                                   ', 'Positive            '),
#  ('Bobbette Pedrocchi                                ', 'Positive            '),
#  ('Bobbi Letham                                      ', 'Positive            '),
#  ('Bobbie Kendred                                    ', 'Positive            '),
#  ('Bobbie Rassell                                    ', 'Positive            '),
#  ('Bobbye Vahey                                      ', 'Positive            '),
#  ('Bobina Albutt                                     ', 'Positive            '),
#  ('Bobina Wroth                                      ', 'Positive            '),
#  ('Bogey McReath                                     ', 'Positive            '),
#  ('Bondon Jeune                                      ', 'Positive            '),
#  ('Bondy Dobel                                       ', 'Positive            '),
#  ('Bone Guittet                                      ', 'Positive            '),
#  ('Bonita Churms                                     ', 'Positive            '),
#  ('Bonny Colaco                                      ', 'Positive            '),
#  ('Bonny Phillip                                     ', 'Positive            '),
#  ('Boony Zanioletti                                  ', 'Positive            '),
#  ('Boote Faldoe                                      ', 'Positive            '),
#  ('Brad Ratt                                         ', 'Positive            '),
#  ('Bradly Arkin                                      ', 'Positive            '),
#  ('Bradney Joan                                      ', 'Positive            '),
#  ('Brady Bartot                                      ', 'Positive            '),
#  ('Bran Jorck                                        ', 'Positive            '),
#  ('Bran Kirsopp                                      ', 'Positive            '),
#  ('Brande Wehden                                     ', 'Positive            '),
#  ('Branden Kainz                                     ', 'Positive            '),
#  ('Brandi Switzer                                    ', 'Positive            '),
#  ('Brandice Drowsfield                               ', 'Positive            '),
#  ('Brandice Laval                                    ', 'Positive            '),
#  ('Brandise Goaley                                   ', 'Positive            '),
#  ('Brandon Vosse                                     ', 'Positive            '),
#  ('Brandtr Cartwight                                 ', 'Positive            '),
#  ('Brandyn Bennit                                    ', 'Positive            '),
#  ('Brandyn Keegan                                    ', 'Positive            '),
#  ('Brant McKelvie                                    ', 'Positive            '),
#  ('Brantley Coling                                   ', 'Positive            '),
#  ('Brantley Galbreath                                ', 'Positive            '),
#  ('Bren Dobing                                       ', 'Positive            '),
#  ('Bren Leynagh                                      ', 'Positive            '),
#  ('Brendan Nurden                                    ', 'Positive            '),
#  ('Brenna Larkcum                                    ', 'Positive            '),
#  ('Brennen Sheriff                                   ', 'Positive            '),
#  ('Brent Cram                                        ', 'Positive            '),
#  ('Brett Alfonsetti                                  ', 'Positive            '),
#  ('Brewer Floodgate                                  ', 'Positive            '),
#  ('Brewster Smouten                                  ', 'Positive            '),
#  ('Brian Udden                                       ', 'Positive            '),
#  ('Brianna Birkby                                    ', 'Positive            '),
#  ('Bridie Hansell                                    ', 'Positive            '),
#  ('Bridie Hrinishin                                  ', 'Positive            '),
#  ('Bridie Kyston                                     ', 'Positive            '),
#  ('Brier McFater                                     ', 'Positive            '),
#  ('Brietta Hammerman                                 ', 'Positive            '),
#  ('Brigg Haskell                                     ', 'Positive            '),
#  ('Briggs Habbergham                                 ', 'Positive            '),
#  ('Brigham Matei                                     ', 'Positive            '),
#  ('Brigid Drysdall                                   ', 'Positive            '),
#  ('Brigit Pauley                                     ', 'Positive            '),
#  ('Brigitte Feake                                    ', 'Positive            '),
#  ('Brigitte Gunn                                     ', 'Positive            '),
#  ('Brigitte Robins                                   ', 'Positive            '),
#  ('Brina Brickell                                    ', 'Positive            '),
#  ('Brina Novis                                       ', 'Positive            '),
#  ('Brinn Christaeas                                  ', 'Positive            '),
#  ('Briny Connechy                                    ', 'Positive            '),
#  ('Brion Offield                                     ', 'Positive            '),
#  ('Brit Foulis                                       ', 'Positive            '),
#  ('Brit Lamb-shine                                   ', 'Positive            '),
#  ('Brita Armistead                                   ', 'Positive            '),
#  ('Britney Banner                                    ', 'Positive            '),
#  ('Britta Lohoar                                     ', 'Positive            '),
#  ('Britte Killshaw                                   ', 'Positive            '),
# ...
#  ('Clarine Moodie                                    ', 'Positive            '),
#  ('Claude Brislen                                    ', 'Positive            '),
#  ('Claude Gullick                                    ', 'Positive            '),
#  ('Claudell Gotcliff                                 ', 'Positive            '),
#  ('Claudia Pester                                    ', 'Positive            '),
#  ('Claudianus Scanlan                                ', 'Positive            '),
#  ('Claudio Maxworthy                                 ', 'Positive            '),
#  ('Claudius Leet                                     ', 'Positive            '),
#  ('Claus Sollitt                                     ', 'Positive            '),
#  ('Clayson Pickworth                                 ', 'Positive            '),
#  ('Clayton Agius                                     ', 'Positive            '),
#  ('Clem Greenough                                    ', 'Positive            '),
#  ('Clementina Dixie                                  ', 'Positive            '),
#  ('Clementius Gilyatt                                ', 'Positive            '),
#  ('Cleon Barwack                                     ', 'Positive            '),
#  ('Clerkclaude Bewshea                               ', 'Positive            '),
#  ('Cleveland Pammenter                               ', 'Positive            '),
#  ('Clevie Jupp                                       ', 'Positive            '),
#  ('Clevie Lyte                                       ', 'Positive            '),
#  ('Clifford Duckham                                  ', 'Positive            '),
#  ('Clio Fone                                         ', 'Positive            '),
#  ('Clo Feighney                                      ', 'Positive            '),
#  ('Clo Ghelerdini                                    ', 'Positive            '),
#  ('Clotilda Eliez                                    ', 'Positive            '),
#  ('Clovis De Lasci                                   ', 'Positive            '),
#  ('Clovis Innott                                     ', 'Positive            '),
#  ('Clyde Roddick                                     ', 'Positive            '),
#  ('Clywd Croshaw                                     ', 'Positive            '),
#  ('Cobb Few                                          ', 'Positive            '),
#  ('Codi Wisby                                        ', 'Positive            '),
#  ('Cody Ebbs                                         ', 'Positive            '),
#  ('Colan Packe                                       ', 'Positive            '),
#  ('Cole Abrahart                                     ', 'Positive            '),
#  ('Coleman Thurner                                   ', 'Positive            '),
#  ('Colene Horley                                     ', 'Positive            '),
#  ('Colet Godlonton                                   ', 'Positive            '),
#  ('Colette Crellin                                   ', 'Positive            '),
#  ('Collen Kerrey                                     ', 'Positive            '),
#  ('Collette Bortoluzzi                               ', 'Positive            '),
#  ('Collin Tidridge                                   ', 'Positive            '),
#  ('Collin Welfair                                    ', 'Positive            '),
#  ('Colline Doge                                      ', 'Positive            '),
#  ('Colline Lethbrig                                  ', 'Positive            '),
#  ('Colly Gonnin                                      ', 'Positive            '),
#  ('Colly Goring                                      ', 'Positive            '),
#  ('Colman Parton                                     ', 'Positive            '),
#  ('Colman Pickston                                   ', 'Positive            '),
#  ('Conan Loton                                       ', 'Positive            '),
#  ('Conant Fellona                                    ', 'Positive            '),
#  ('Concettina Bony                                   ', 'Positive            '),
#  ('Concordia Cappell                                 ', 'Positive            '),
#  ('Conn Girke                                        ', 'Positive            '),
#  ('Conney Reuss                                      ', 'Positive            '),
#  ('Conni Pocke                                       ', 'Positive            '),
#  ('Conny Boughton                                    ', 'Positive            '),
#  ('Conrade Erley                                     ', 'Positive            '),
#  ('Conrado Hanford                                   ', 'Positive            '),
#  ('Constancia Yele                                   ', 'Positive            '),
#  ('Constanta Lesurf                                  ', 'Positive            '),
#  ('Constantin Louth                                  ', 'Positive            '),
#  ('Constantine Ghilardi                              ', 'Positive            '),
#  ('Constantine Nowill                                ', 'Positive            '),
#  ('Constantino Ortells                               ', 'Positive            '),
#  ('Consuelo Gerger                                   ', 'Positive            '),
#  ('Conway Newark                                     ', 'Positive            '),
#  ('Conway Rosenboim                                  ', 'Positive            '),
#  ('Coop McEttigen                                    ', 'Positive            '),
#  ('Coop Scard                                        ', 'Positive            '),
#  ('Cora Waddoups                                     ', 'Positive            '),
#  ('Corabel Sehorsch                                  ', 'Positive            '),
#  ('Corabelle Nockolds                                ', 'Positive            '),
#  ('Coralie Powter                                    ', 'Positive            '),
#  ('Corbet Baleine                                    ', 'Positive            '),
#  ('Corbin Broome                                     ', 'Positive            '),
#  ('Cord Joerning                                     ', 'Positive            '),
#  ('Cordelie Guidoni                                  ', 'Positive            '),
#  ('Cordelie Underwood                                ', 'Positive            '),
#  ('Cordi Vassano                                     ', 'Positive            '),
#  ('Cordie Kreuzer                                    ', 'Positive            '),
#  ('Cordy Busher                                      ', 'Positive            '),
#  ('Cordy Pitcher                                     ', 'Positive            '),
#  ('Cordy Truman                                      ', 'Positive            '),
#  ('Coreen Kindleysides                               ', 'Positive            '),
#  ('Corella Eite                                      ', 'Positive            '),
#  ('Corella Paullin                                   ', 'Positive            '),
#  ('Corenda Trimme                                    ', 'Positive            '),
#  ('Corene Tallet                                     ', 'Positive            '),
#  ('Corey Leamy                                       ', 'Positive            '),
#  ('Corey Rothermel                                   ', 'Positive            '),
#  ('Corey Spradbrow                                   ', 'Positive            '),
#  ('Cori Juppe                                        ', 'Positive            '),
#  ('Corina Crosfeld                                   ', 'Positive            '),
#  ('Corliss Barrow                                    ', 'Positive            '),
#  ('Corliss Bence                                     ', 'Positive            '),
#  ('Cornela Demead                                    ', 'Positive            '),
#  ('Cornelius Clemenzo                                ', 'Positive            '),
#  ('Cornell Enderby                                   ', 'Positive            '),
#  ('Corny Shipperbottom                               ', 'Positive            '),
#  ('Correna McGillivray                               ', 'Positive            '),
#  ('Corri Hanscomb                                    ', 'Positive            '),
#  ('Corrie Khosa                                      ', 'Positive            '),
#  ('Corty Flannigan                                   ', 'Positive            '),
#  ('Cos Auden                                         ', 'Positive            '),
#  ('Cos Chevolleau                                    ', 'Positive            '),
#  ('Cosetta Beales                                    ', 'Positive            '),
#  ('Cosetta Figin                                     ', 'Positive            '),
#  ('Cosetta Ickovitz                                  ', 'Positive            '),
#  ('Cosette Rawling                                   ', 'Positive            '),
#  ('Costa Madill                                      ', 'Positive            '),
#  ('Cozmo Hearne                                      ', 'Positive            '),
#  ('Craggie Cockling                                  ', 'Positive            '),
#  ('Craggie Fernandes                                 ', 'Positive            '),
#  ('Crawford Ortega                                   ', 'Positive            '),
#  ('Creigh Hargess                                    ', 'Positive            '),
#  ('Creight Plumer                                    ', 'Positive            '),
#  ('Cris Hagstone                                     ', 'Positive            '),
#  ('Cris Hodges                                       ', 'Positive            '),
#  ('Cris Sallowaye                                    ', 'Positive            '),
#  ('Cristabel Blas                                    ', 'Positive            '),
#  ('Cristen Floch                                     ', 'Positive            '),
#  ('Cristiano Haet                                    ', 'Positive            '),
#  ('Cristobal Twinborne                               ', 'Positive            '),
#  ('Cross Jelliman                                    ', 'Positive            '),
#  ('Crystal Dumsday                                   ', 'Positive            '),
#  ('Crystal Melesk                                    ', 'Positive            '),
#  ('Crystie Kellen                                    ', 'Positive            '),
#  ('Cullie Kees                                       ', 'Positive            '),
#  ('Cullie Tisor                                      ', 'Positive            '),
#  ('Culver McCloughlin                                ', 'Positive            '),
#  ("Curcio O'Dunniom                                  ", 'Positive            '),
#  ('Curr MacKaig                                      ', 'Positive            '),
#  ('Currey Mitchelson                                 ', 'Positive            '),
#  ('Curry Scottini                                    ', 'Positive            '),
#  ('Curt Frangleton                                   ', 'Positive            '),
#  ('Curtis Bentje                                     ', 'Positive            '),
#  ('Curtis Hair                                       ', 'Positive            '),
#  ('Curtis Jertz                                      ', 'Positive            '),
#  ('Curtis McCunn                                     ', 'Positive            '),
#  ('Cynde Longwood                                    ', 'Positive            '),
#  ('Cyndy McSwan                                      ', 'Positive            '),
#  ('Cyndy Pedlow                                      ', 'Positive            '),
#  ('Cynthea Alejandre                                 ', 'Positive            '),
#  ('Cynthea Antuk                                     ', 'Positive            '),
#  ('Cyril Jasik                                       ', 'Positive            '),
#  ('Cyrill Realph                                     ', 'Positive            '),
#  ('Cyrille Swalteridge                               ', 'Positive            '),
#  ('Cyrus Hargey                                      ', 'Positive            '),
#  ("D'arcy Hearn                                      ", 'Positive            '),
#  ('Dacey Alebrooke                                   ', 'Positive            '),
#  ('Dacy Schout                                       ', 'Positive            '),
#  ('Dael Elston                                       ', 'Positive            '),
#  ('Dael Mac                                          ', 'Positive            '),
#  ('Daffie Raye                                       ', 'Positive            '),
#  ('Daffy Artus                                       ', 'Positive            '),
#  ('Dagny Yarrall                                     ', 'Positive            '),
#  ('Daile Aylott                                      ', 'Positive            '),
#  ('Daisi Dono                                        ', 'Positive            '),
#  ('Daisi Garces                                      ', 'Positive            '),
#  ('Daisi Grabert                                     ', 'Positive            '),
#  ('Daisy Wycliff                                     ', 'Positive            '),
#  ('Dale Castan                                       ', 'Positive            '),
#  ('Dale Minnis                                       ', 'Positive            '),
#  ('Dalia Peele                                       ', 'Positive            '),
#  ('Dallas Light                                      ', 'Positive            '),
#  ('Dalli Knappe                                      ', 'Positive            '),
#  ('Dallis Athey                                      ', 'Positive            '),
#  ('Dallis Bezzant                                    ', 'Positive            '),
#  ('Dalston Fragino                                   ', 'Positive            '),
#  ('Dalt Witherdon                                    ', 'Positive            '),
#  ('Damara Itzakovitz                                 ', 'Positive            '),
#  ('Damaris Zamudio                                   ', 'Positive            '),
#  ('Dame Kernes                                       ', 'Positive            '),
#  ('Damita Burless                                    ', 'Positive            '),
#  ('Dana Everal                                       ', 'Positive            '),
#  ('Dana MacGillicuddy                                ', 'Positive            '),
#  ('Danella Beresfore                                 ', 'Positive            '),
#  ('Danella Patershall                                ', 'Positive            '),
#  ('Danella Staley                                    ', 'Positive            '),
#  ('Danette Astell                                    ', 'Positive            '),
#  ('Dani Dubery                                       ', 'Positive            '),
#  ('Danie Purver                                      ', 'Positive            '),
#  ('Daniella Canfield                                 ', 'Positive            '),
#  ('Danita Brandel                                    ', 'Positive            '),
#  ('Dannie Scimoni                                    ', 'Positive            '),
#  ('Danya Holton                                      ', 'Positive            '),
#  ('Danyette Fealy                                    ', 'Positive            '),
#  ('Daphene Davidovic                                 ', 'Positive            '),
#  ('Daphna Tallow                                     ', 'Positive            '),
#  ('Daphne Curtoys                                    ', 'Positive            '),
#  ('Dar Balassi                                       ', 'Positive            '),
#  ('Dar Hintze                                        ', 'Positive            '),
#  ('Darb Jancic                                       ', 'Positive            '),
#  ('Darbee Delacroux                                  ', 'Positive            '),
#  ('Darbie Bowie                                      ', 'Positive            '),
#  ('Darby Stonhouse                                   ', 'Positive            '),
#  ('Darby Triggle                                     ', 'Positive            '),
#  ('Darcee Minithorpe                                 ', 'Positive            '),
#  ...]

# %% [markdown]
# So we have 7.098 total from 32.941 total customers that give us 'Very Positive' and 'Positive' sentiment.
